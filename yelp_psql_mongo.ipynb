# %%
# Install psycopg3 to Connect to PostgreSQL, create a table, and insert data
# pip install psycopg2-binary

# %%
import psycopg2
import pandas as pd
import numpy as np
import random
from random import randrange
import json
import os
import ast
from pymongo import MongoClient
import time
import pprint

# %% [markdown]
# ## Data Cleaning and Sampling (Not to run again since the CSVs have been creaed)

# %%
def reservoir_sample(data, n, k):
  # fill the reservoir array
  r = []
  for i in range(k):
    r.append(data[i])

  # replace elements w/gradually decreasing prob.
  for i in range(k, n):
    # generates a uniform integer between 0 and a-1
    j = randrange(i+1)
    if j < k:
        r[j] = data[i]

  return r

# %%
def fix_json_columns(df, columns):
    for col in columns:
        if col in df.columns:
            def safe_parse(x):
                if pd.isnull(x):
                    return None
                if isinstance(x, dict):
                    return json.dumps(x)
                if isinstance(x, str):
                    try:
                        parsed = ast.literal_eval(x)
                        return json.dumps(parsed)
                    except (ValueError, SyntaxError):
                        return None  # or keep as is: return x
                return None
            df[col] = df[col].apply(safe_parse)
    return df

# %%
# Create data folder
os.makedirs("data", exist_ok=True)

# %%
print("Sampling 15,000 businesses using reservoir sampling...")

# Load business dataset
business_file = pd.read_json("yelp_academic_dataset_business.json", lines=True)
business_dict = business_file.to_dict(orient='records')

# Sample business dataset with a size of 15000
n = len(business_file)
k = 15000

business_sample = reservoir_sample(business_dict, n, k)
business_df = pd.DataFrame(business_sample)

# Clean data
business_df.dropna(subset=['business_id', 'name', 'city', 'stars', 'latitude', 'longitude'], inplace=True)
business_df = business_df[business_df['stars'] > 0]
business_df = business_df[business_df['review_count'] > 0]
business_df = business_df.drop_duplicates(subset='business_id')
business_df = fix_json_columns(business_df, ['attributes', 'hours'])

# Save cleaned businesses
business_df.to_csv('data/business_sample.csv', index=False)
print(f"Saved {len(business_df)} business records.")

# Extract business_id from business_df
business_ids = set(business_df["business_id"])
# Out:
# Sampling 15,000 businesses using reservoir sampling...
# Saved 15000 business records.

# %%
# Load and filter review dataset
print("Filtering reviews for sampled businesses...")
review_sample = []

with open('yelp_academic_dataset_review.json', 'r') as f:
    for line in f:
        review = json.loads(line)
        if review['business_id'] in business_ids:
            review_sample.append(review)

review_df = pd.DataFrame(review_sample)

# Clean data
review_df.dropna(subset=['review_id', 'user_id', 'business_id', 'text', 'stars', 'date'], inplace=True)
review_df = review_df[review_df['stars'] > 0]
review_df = review_df.drop_duplicates(subset='review_id')

# Save cleaned reviews
review_df.to_csv('data/review_sample.csv', index=False)
print(f"Saved {len(review_df)} review records.")

# Extract user_id from df_review_sample
user_ids = set(review_df["user_id"])
# Out:
# Filtering reviews for sampled businesses...
# Saved 685279 review records.

# %%
# Load and filter user dataset
print("Filtering users who wrote sampled reviews...")
user_sample = []

with open('yelp_academic_dataset_user.json', 'r') as f:
    for line in f:
        user = json.loads(line)
        if user['user_id'] in user_ids:
            user_sample.append(user)

user_df = pd.DataFrame(user_sample)

# Clean data
user_df.dropna(subset=['user_id', 'name', 'review_count', 'yelping_since'], inplace=True)
user_df = user_df[user_df['review_count'] > 0]
user_df = user_df.drop_duplicates(subset='user_id')

# Save cleaned users
user_df.to_csv("data/user_sample.csv", index=False)
print(f"Saved {len(user_df)} users.")
# Out:
# Filtering users who wrote sampled reviews...
# Saved 413059 users.

# %%
l=[business_df, review_df, user_df]
for df in l:
    print(f"Rows after cleaning: {len(df)}")
    print("Null check:")
    print(df.isnull().sum())
    print(df.columns)
    print('\n')
# Out:
# Rows after cleaning: 15000
# Null check:
# business_id        0
# name               0
# address            0
# city               0
# state              0
# postal_code        0
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# attributes      1398
# categories        14
# hours           2253
# dtype: int64
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')
#
#
# Rows after cleaning: 685279
# Null check:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date'],
#       dtype='object')
#
#
# Rows after cleaning: 413059
# Null check:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %% [markdown]
# ## Create PostgreSQL Database

# %%
# Connect to the default database
conn = psycopg2.connect("dbname=postgres user=kaiting host=localhost")
conn.autocommit = True
cur = conn.cursor()

# Create `yelp` database if it doesn't exist
cur.execute("SELECT 1 FROM pg_database WHERE datname = 'yelp'")
if not cur.fetchone():
    cur.execute("CREATE DATABASE yelp")
    print("Database 'yelp' created.")
else:
    print("Database 'yelp' already exists.")
# Out:
# Database 'yelp' already exists.

# %% [markdown]
# ## Create Tables (Do not run multiple times if created)

# %%
cur.execute("""
DROP TABLE IF EXISTS business;
""")

cur.execute("""
CREATE TABLE IF NOT EXISTS business (
    business_id TEXT PRIMARY KEY,
    name TEXT,
    address TEXT,
    city TEXT,
    state TEXT,
    postal_code TEXT,
    latitude FLOAT,
    longitude FLOAT,
    stars FLOAT,
    review_count INT,
    is_open INT,
    attributes JSONB,
    categories TEXT,
    hours JSONB
);
""")

cur.execute("""
DROP TABLE IF EXISTS review;
""")

cur.execute("""
CREATE TABLE IF NOT EXISTS review (
    review_id TEXT PRIMARY KEY,
    user_id TEXT,
    business_id TEXT,
    stars FLOAT,
    useful INT,
    funny INT,
    cool INT,
    text TEXT,
    date DATE
);
""")

cur.execute("""
DROP TABLE IF EXISTS users;
""")

cur.execute("""
CREATE TABLE IF NOT EXISTS users (
    user_id TEXT PRIMARY KEY,
    name TEXT,
    review_count INT,
    yelping_since DATE,
    useful INT,
    funny INT,
    cool INT,
    elite TEXT,
    friends TEXT,
    fans INT,
    average_stars FLOAT,
    compliment_hot INT,
    compliment_more INT,
    compliment_profile INT,
    compliment_cute INT,
    compliment_list INT,
    compliment_note INT,
    compliment_plain INT,
    compliment_cool INT,
    compliment_funny INT,
    compliment_writer INT,
    compliment_photos INT
);
""")

conn.commit()
print("Tables created successfully.")

with open('data/business_sample.csv', 'r') as f:
    cur.copy_expert("COPY business FROM STDIN WITH CSV HEADER DELIMITER ','", f)
conn.commit()

with open('data/review_sample.csv', 'r') as f:
    cur.copy_expert("COPY review FROM STDIN WITH CSV HEADER DELIMITER ','", f)
conn.commit()

with open('data/user_sample.csv', 'r') as f:
    cur.copy_expert("COPY users FROM STDIN WITH CSV HEADER DELIMITER ','", f)
conn.commit()

print("Data loaded successfully.")
# Out:
# Tables created successfully.
# Data loaded successfully.

# %%
# Sample query test
cur.execute("""
SELECT * 
FROM business
LIMIT 5;
""")

# Fetch and display results
results = cur.fetchall()
for row in results:
    print(row)
# Out:
# ('DBVINWAA-BJdS_-g0vlfGg', 'Zazen', '832 W Lancaster Ave', 'Bryn Mawr', 'PA', '19010', 40.0218819, -75.3192112, 4.5, 24, 0, {'GoodForKids': 'True', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'ByAppointmentOnly': 'False', 'RestaurantsPriceRange2': '2', 'BusinessAcceptsCreditCards': 'True'}, 'Hair Removal, Makeup Artists, Hair Salons, Waxing, Nail Salons, Blow Dry/Out Services, Beauty & Spas', {'Friday': '10:0-19:0', 'Monday': '11:30-18:0', 'Sunday': '11:30-16:30', 'Tuesday': '10:0-18:0', 'Saturday': '9:30-17:30', 'Thursday': '10:0-19:0', 'Wednesday': '10:0-18:0'})
# ('NCwvtN1oZvLamyOhZ2OzAQ', 'LA Fitness', '1435 Walnut Street', 'Philadelphia', 'PA', '19102', 39.9497264263, -75.1657220984, 2.0, 39, 0, {'GoodForKids': 'False', 'BusinessAcceptsCreditCards': 'False'}, 'Sports Clubs, Gyms, Trainers, Fitness & Instruction, Active Life', {'Friday': '6:0-21:0', 'Monday': '5:0-23:0', 'Sunday': '8:0-18:0', 'Tuesday': '5:0-23:0', 'Saturday': '8:0-18:0', 'Thursday': '5:0-23:0', 'Wednesday': '5:0-23:0'})
# ('ye_Vi7HzzpMaGHRbzZdTSw', 'Bistro On Bridge', '212 Bridge St', 'Phoenixville', 'PA', '19460', 40.1341124629, -75.5175090752, 3.5, 234, 1, {'WiFi': "'no'", 'HasTV': 'True', 'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': True, 'video': False, 'karaoke': False}", 'Caters': 'True', 'Alcohol': "u'full_bar'", 'Ambience': "{'touristy': False, 'hipster': None, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': None, 'upscale': False, 'classy': False, 'casual': True}", 'HappyHour': 'True', 'BestNights': "{'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}", 'NoiseLevel': "u'loud'", 'BikeParking': 'True', 'GoodForKids': 'True', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}", 'GoodForDancing': 'False', 'OutdoorSeating': 'True', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'RestaurantsAttire': "u'casual'", 'RestaurantsTakeOut': 'True', 'RestaurantsDelivery': 'True', 'RestaurantsPriceRange2': '2', 'RestaurantsReservations': 'True', 'RestaurantsTableService': 'True', 'RestaurantsGoodForGroups': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'American (New), Restaurants, Nightlife, Burgers, Sports Bars, Bars, American (Traditional)', {'Friday': '11:0-1:0', 'Monday': '0:0-0:0', 'Sunday': '10:0-22:0', 'Tuesday': '11:0-23:0', 'Saturday': '11:0-1:0', 'Thursday': '11:30-16:0', 'Wednesday': '11:0-23:0'})
# ('oTuVT19lWmG-Z54shcSIqA', 'Purple Haze of Tyrone', '3809 Tyrone Blvd N', 'Saint Petersburg', 'FL', '33709', 27.8066846647, -82.7492884343, 2.0, 13, 1, {'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}, 'Shopping, Tobacco Shops', None)
# ('ZM6bURQakQqEYBE9ZOlyug', 'Costco Tire Center', '2200 Harvard Way', 'Reno', 'NV', '89502', 39.503107, -119.785107, 2.5, 13, 1, None, 'Tires, Automotive', None)

# %% [markdown]
# ## Benchmark Set of Tasks

# %% [markdown]
# ### Query 1: Top 5 Highest Rated Businesses

# %%
cur.execute("""
SELECT name, stars, review_count
FROM business
ORDER BY stars DESC, review_count DESC
LIMIT 5;
""")

results = cur.fetchall()
print("\n Benchmark Query 1: Top 5 Highest Rated Businesses:")
for row in results:
    print(row)
# Out:
#  Benchmark Query 1: Top 5 Highest Rated Businesses:
# ('Blues City Deli', 5.0, 991)
# ('Carlillos Cocina', 5.0, 799)
# ('Free Tours By Foot', 5.0, 769)
# ('Tumerico', 5.0, 705)
# ('Yats', 5.0, 623)

# %% [markdown]
# ### Query 2: Cities with the Most Businesses

# %%
cur.execute("""
SELECT city, COUNT(*) as num_businesses
FROM business
GROUP BY city
ORDER BY num_businesses DESC
LIMIT 5;
""")

results = cur.fetchall()
print("\n Benchmark Query 2: Cities with the Most Businesses:")
for row in results:
    print(row)
# Out:
#  Benchmark Query 2: Cities with the Most Businesses:
# ('Philadelphia', 14569)
# ('Tucson', 9250)
# ('Tampa', 9050)
# ('Indianapolis', 7540)
# ('Nashville', 6971)

# %% [markdown]
# ### Query 3: Average Review Stars by City

# %%
cur.execute("""
SELECT city, ROUND(AVG(stars)::numeric, 2) as avg_stars
FROM business
GROUP BY city
ORDER BY avg_stars DESC
LIMIT 10;
""")

results = cur.fetchall()
print("\n Benchmark Query 3: Average Review Stars by City:")
for row in results:
    print(row)
# Out:
#  Benchmark Query 3: Average Review Stars by City:
# ('Chicago', Decimal('5.00'))
# ('Center City Philadelphia', Decimal('5.00'))
# ('Chattanooga', Decimal('5.00'))
# ('Bridgeton ', Decimal('5.00'))
# ('Arizona', Decimal('5.00'))
# ('Catalina Foothills', Decimal('5.00'))
# ('Belleville ', Decimal('5.00'))
# ('Carpinteria ', Decimal('5.00'))
# ('Aliso Viejo', Decimal('5.00'))
# ('COLMAR', Decimal('5.00'))

# %% [markdown]
# ### Query 4: Users Who Wrote More Than 50 Reviews

# %%
cur.execute("""
SELECT name, review_count
FROM users
WHERE review_count > 50
ORDER BY review_count DESC
LIMIT 10;
""")

results = cur.fetchall()
print("\n Benchmark Query 4: Users Who Wrote More Than 50 Reviews:")
for row in results:
    print(row)
# Out:
#  Benchmark Query 4: Users Who Wrote More Than 50 Reviews:
# ('Fox', 17473)
# ('Victor', 16978)
# ('Bruce', 16567)
# ('Shila', 12868)
# ('Kim', 9941)
# ('Nijole', 8363)
# ('Vincent', 8354)
# ('George', 7738)
# ('Kenneth', 6766)
# ('Jennifer', 6679)

# %% [markdown]
# ### Query 5: Most Common Categories (simple)

# %%
cur.execute("""
SELECT categories, COUNT(*) as category_count
FROM business
GROUP BY categories
ORDER BY category_count DESC
LIMIT 10;
""")

results = cur.fetchall()
print("\n Benchmark Query 5: Most Common Categories:")
for row in results:
    print(row)
# Out:
#  Benchmark Query 5: Most Common Categories:
# ('Beauty & Spas, Nail Salons', 1012)
# ('Restaurants, Pizza', 935)
# ('Nail Salons, Beauty & Spas', 934)
# ('Pizza, Restaurants', 823)
# ('Restaurants, Mexican', 728)
# ('Restaurants, Chinese', 708)
# ('Mexican, Restaurants', 672)
# ('Chinese, Restaurants', 651)
# ('Food, Coffee & Tea', 508)
# ('Beauty & Spas, Hair Salons', 493)

# %% [markdown]
# ## Load MongoDB

# %%
# Connect to MongoDB server 
client = MongoClient('localhost', 27017)
db = client['yelp']

# Load data
def load_csv_to_mongo(csv_path, collection_name):
    print(f"Loading {collection_name}...")
    df = pd.read_csv(csv_path)
    records = df.to_dict(orient='records')
    db.collection_name.drop()
    db.collection_name.insert_many(records)
    print(f"Inserted {len(records)} records into {collection_name}.")

load_csv_to_mongo('data/business_sample.csv', 'business')
load_csv_to_mongo('data/review_sample.csv', 'review')
load_csv_to_mongo('data/user_sample.csv', 'users')

print("All data loaded into MongoDB successfully!")
# Out:
# Loading business...
# Inserted 15000 records into business.
# Loading review...
# Inserted 685279 records into review.
# Loading users...
# Inserted 413059 records into users.
# All data loaded into MongoDB successfully!

# %% [markdown]
# ## Task Selection

# %% [markdown]
# ### 1. Number of 5-Star Reviews per Business

# %%
cur.execute("""
SELECT business_id, COUNT(*) AS five_star_reviews
FROM review
WHERE stars = 5
GROUP BY business_id
ORDER BY five_star_reviews DESC
LIMIT 10;
""")

results = cur.fetchall()
print("Number of 5-Star Reviews per Business:")
for row in results:
    print(row)
# Out:
# Number of 5-Star Reviews per Business:
# ('ac1AeYqs8Z4_e2X5M3if2A', 4012)
# ('_C7QiQQc47AOEv4PE3Kong', 3095)
# ('yPSejq3_erxo9zdVYTBnZA', 2693)
# ('I_3LMZ_1m2mzR0oLIOePIg', 2675)
# ('6ajnOk0GcY9xbb5Ocaw8Gw', 1574)
# ('GuzbBFraIq-fbkjfvaTRvg', 1523)
# ('3YqUe2FTCQr0pPVK8oCv6Q', 1367)
# ('vN6v8m4DO45Z4pp8yxxF_w', 1338)
# ('8uF-bhJFgT4Tn6DTb27viA', 1309)
# ('PY9GRfzr4nTZeINf346QOw', 1131)

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT business_id, COUNT(*) AS five_star_reviews
FROM review
WHERE stars = 5
GROUP BY business_id
ORDER BY five_star_reviews DESC
LIMIT 10;
""")

plan = cur.fetchall()
print("Execution Plan for usinesses Active in 2018 But Inactive 2019–2020:")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for usinesses Active in 2018 But Inactive 2019–2020:
# ac1AeYqs8Z4_e2X5M3if2A
# _C7QiQQc47AOEv4PE3Kong
# yPSejq3_erxo9zdVYTBnZA
# I_3LMZ_1m2mzR0oLIOePIg
# 6ajnOk0GcY9xbb5Ocaw8Gw
# GuzbBFraIq-fbkjfvaTRvg
# 3YqUe2FTCQr0pPVK8oCv6Q
# vN6v8m4DO45Z4pp8yxxF_w
# 8uF-bhJFgT4Tn6DTb27viA
# PY9GRfzr4nTZeINf346QOw

# %% [markdown]
# ### 2. Avg rating given by each user

# %% [markdown]
# #### SQL

# %%
cur.execute("""
SELECT r.user_id, COUNT(r.review_id) AS review_count
FROM review r
GROUP BY r.user_id
ORDER BY review_count DESC
LIMIT 5;
""")

results = cur.fetchall()
print("UAvg rating given by each user:")
for row in results:
    print(row)
# Out:
# UAvg rating given by each user:
# ('_BcWyKQL16ndpBdggh2kNA', 287)
# ('Xw7ZjaGfr0WNVt6s_5KZfA', 187)
# ('0Igx-a1wAstiBDerGxXk2A', 181)
# ('-G7Zkl1wIWBBmD0KRy_sCw', 168)
# ('ET8n-r7glWYqZhuR6GcdNw', 162)

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT r.user_id, COUNT(r.review_id) AS review_count
FROM review r
GROUP BY r.user_id
ORDER BY review_count DESC
LIMIT 5;
""")

plan = cur.fetchall()
print("Execution Plan for Users Who Reviewed in 3+ Different Cities:")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for Users Who Reviewed in 3+ Different Cities:
# Limit  (cost=143282.70..143282.71 rows=5 width=31) (actual time=450.844..454.823 rows=5 loops=1)
#   ->  Sort  (cost=143282.70..143701.04 rows=167337 width=31) (actual time=450.842..454.821 rows=5 loops=1)
#         Sort Key: (count(review_id)) DESC
#         Sort Method: top-N heapsort  Memory: 25kB
#         ->  Finalize GroupAggregate  (cost=94711.63..140503.29 rows=167337 width=31) (actual time=198.364..429.305 rows=413069 loops=1)
#               Group Key: user_id
#               ->  Gather Merge  (cost=94711.63..137156.55 rows=334674 width=31) (actual time=198.357..370.180 rows=512146 loops=1)
#                     Workers Planned: 2
#                     Workers Launched: 2
#                     ->  Partial GroupAggregate  (cost=93711.61..97526.84 rows=167337 width=31) (actual time=190.510..268.327 rows=170715 loops=3)
#                           Group Key: user_id
#                           ->  Sort  (cost=93711.61..94425.56 rows=285582 width=46) (actual time=190.505..237.689 rows=228426 loops=3)
#                                 Sort Key: user_id
#                                 Sort Method: external merge  Disk: 13560kB
#                                 Worker 0:  Sort Method: external merge  Disk: 11536kB
#                                 Worker 1:  Sort Method: external merge  Disk: 12528kB
#                                 ->  Parallel Seq Scan on review r  (cost=0.00..59047.82 rows=285582 width=46) (actual time=0.295..72.660 rows=228426 loops=3)
# Planning Time: 0.144 ms
# Execution Time: 459.806 ms

# %% [markdown]
# #### MQL

# %%
pipeline = [
    {"$group": {"_id": "$user_id", "review_count": {"$sum": 1}}},
    {"$sort": {"review_count": -1}},
    {"$limit": 5}
]

results = list(db.review.aggregate(pipeline))
# pd.DataFrame(results)
print("Avg rating given by each user (MongoDB):")
pprint.pprint(results)
for row in results:
    print(f"Number of results: {len(results)}")
    print(row)
# Out:
# Avg rating given by each user (MongoDB):
# [{'_id': '_BcWyKQL16ndpBdggh2kNA', 'review_count': 1431},
#  {'_id': 'Xw7ZjaGfr0WNVt6s_5KZfA', 'review_count': 845},
#  {'_id': '0Igx-a1wAstiBDerGxXk2A', 'review_count': 827},
#  {'_id': '-G7Zkl1wIWBBmD0KRy_sCw', 'review_count': 779},
#  {'_id': 'bYENop4BuQepBjM1-BI3fA', 'review_count': 742}]
# Number of results: 5
# {'_id': '_BcWyKQL16ndpBdggh2kNA', 'review_count': 1431}
# Number of results: 5
# {'_id': 'Xw7ZjaGfr0WNVt6s_5KZfA', 'review_count': 845}
# Number of results: 5
# {'_id': '0Igx-a1wAstiBDerGxXk2A', 'review_count': 827}
# Number of results: 5
# {'_id': '-G7Zkl1wIWBBmD0KRy_sCw', 'review_count': 779}
# Number of results: 5
# {'_id': 'bYENop4BuQepBjM1-BI3fA', 'review_count': 742}

# %%
# Enable profiling for all operations
db.command("profile", 2)

# Run aggregation query
pipeline = [
    {"$group": {"_id": "$user_id", "avg_rating": {"$avg": "$stars"}}},
    {"$sort": {"avg_rating": -1}},
    {"$limit": 10}
]
result = list(db.review.aggregate(pipeline))

# Ensure profiling is logged
time.sleep(1)

# Fetch latest profiling info
profile = db["system.profile"].find(
    {"ns": "yelp.review", "op": "command", "command.aggregate": "review"}
).sort("ts", -1).limit(1)

# Show profiling result
for doc in profile:
    pprint.pprint(doc)

# Turn off profiling to avoid overhead
db.command("profile", 0)
# Out:
# {'allUsers': [],
#  'client': '127.0.0.1',
#  'command': {'$db': 'yelp',
#              'aggregate': 'review',
#              'cursor': {},
#              'lsid': {'id': Binary(b'<\xe6ve[\xf7F\xd7\xba\x97\x1d\x1b\x8fA</', 4)},
#              'pipeline': [{'$group': {'_id': '$user_id',
#                                       'avg_rating': {'$avg': '$stars'}}},
#                           {'$sort': {'avg_rating': -1}},
#                           {'$limit': 10}]},
#  'cursorExhausted': True,
#  'docsExamined': 685279,
#  'flowControl': {},
#  'hasSortStage': True,
#  'keysExamined': 0,
#  'locks': {'Global': {'acquireCount': {'r': 73}}},
#  'millis': 920,
#  'nreturned': 10,
#  'ns': 'yelp.review',
#  'numYield': 34,
#  'op': 'command',
#  'planCacheKey': '4714AAE1',
#  'planCacheShapeHash': '1BB56745',
#  'planSummary': 'COLLSCAN',
#  'planningTimeMicros': 3269,
#  'protocol': 'op_msg',
#  'queryFramework': 'sbe',
#  'queryHash': '1BB56745',
#  'queryShapeHash': 'B93C95016FFAF0176AFE39DF49A5130593C64A3E253F6539A71AD809A56A725C',
#  'responseLength': 700,
#  'storage': {},
#  'ts': datetime.datetime(2025, 5, 7, 2, 38, 1, 796000),
#  'user': ''}
# {'was': 2, 'slowms': 100, 'sampleRate': 1.0, 'ok': 1.0}

# %% [markdown]
# ### 3. Users who reviewed businesses in 3+ different cities

# %% [markdown]
# #### SQL

# %%
cur.execute("""
SELECT r.user_id, COUNT(DISTINCT b.city) AS num_cities
FROM review r
JOIN business b ON r.business_id = b.business_id
GROUP BY r.user_id
HAVING COUNT(DISTINCT b.city) >= 3
ORDER BY num_cities DESC
LIMIT 10;
""")

results = cur.fetchall()
print("Users Who Reviewed in 3+ Different Cities:")
for row in results:
    print(row)
# Out:
# Users Who Reviewed in 3+ Different Cities:
# ('_BcWyKQL16ndpBdggh2kNA', 55)
# ('-G7Zkl1wIWBBmD0KRy_sCw', 50)
# ('vmUqcqMjlWoBM6qfmUXgyQ', 37)
# ('RCZ5M9o2-fxgFuurpmEs3w', 36)
# ('GcdYgbaF75vj7RO6EZhPOQ', 36)
# ('ppsm8EDKjA1fp1yTCP3RrQ', 36)
# ('ouODopBKF3AqfCkuQEnrDg', 34)
# ('XzpJ4uHkxARCFQiZ9bffyg', 33)
# ('nxNO7_6U2Nu90v0IdnEhIg', 32)
# ('zUk_Ww2q1At1QSyRbUjIGQ', 31)

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT r.user_id, COUNT(DISTINCT b.city) AS num_cities
FROM review r
JOIN business b ON r.business_id = b.business_id
GROUP BY r.user_id
HAVING COUNT(DISTINCT b.city) >= 3
ORDER BY num_cities DESC;
""")

plan = cur.fetchall()
print("Execution Plan for Users Who Reviewed in 3+ Different Cities:")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for Users Who Reviewed in 3+ Different Cities:
# Sort  (cost=178246.86..178396.12 rows=59705 width=31) (actual time=900.507..901.018 rows=18267 loops=1)
#   Sort Key: (count(DISTINCT b.city)) DESC
#   Sort Method: quicksort  Memory: 1625kB
#   ->  GroupAggregate  (cost=165666.34..173510.59 rows=59705 width=31) (actual time=546.057..899.005 rows=18267 loops=1)
#         Group Key: r.user_id
#         Filter: (count(DISTINCT b.city) >= 3)
#         Rows Removed by Filter: 426534
#         ->  Sort  (cost=165666.34..167534.78 rows=747377 width=33) (actual time=545.988..798.991 rows=746656 loops=1)
#               Sort Key: r.user_id, b.city
#               Sort Method: external merge  Disk: 31824kB
#               ->  Hash Join  (cost=1689.50..72317.69 rows=747377 width=33) (actual time=4.234..239.311 rows=746656 loops=1)
#                     Hash Cond: (r.business_id = b.business_id)
#                     ->  Seq Scan on review r  (cost=0.00..68665.77 rows=747377 width=46) (actual time=0.011..140.524 rows=746656 loops=1)
#                     ->  Hash  (cost=1502.00..1502.00 rows=15000 width=33) (actual time=4.216..4.216 rows=15000 loops=1)
#                           Buckets: 16384  Batches: 1  Memory Usage: 1084kB
#                           ->  Seq Scan on business b  (cost=0.00..1502.00 rows=15000 width=33) (actual time=0.003..3.045 rows=15000 loops=1)
# Planning Time: 0.121 ms
# Execution Time: 904.156 ms

# %% [markdown]
# #### MQL

# %%
pipeline = [
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    { "$unwind": "$business_info" },
    {
        "$group": {
            "_id": "$user_id",
            "cities_reviewed": { "$addToSet": "$business_info.city" }
        }
    },
    {
        "$project": {
            "user_id": "$_id",
            "num_cities": { "$size": "$cities_reviewed" }
        }
    },
    { "$match": { "num_cities": { "$gte": 3 } } },
    { "$sort": { "num_cities": -1 } },
    { "$limit": 10 }
]

results = list(db.review.aggregate(pipeline))
print("Users Who Reviewed in 3+ Cities (MongoDB):")
for row in results:
    print(f"Number of results: {len(results)}")
    print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l_/qqmwldsd40dccgp2bsqp6cx00000gn/T/ipykernel_68082/2745739932.py in <module>
#      26 ]
#      27
# ---> 28 results = list(db.review.aggregate(pipeline))
#      29 print("Users Who Reviewed in 3+ Cities (MongoDB):")
#      30 for row in results:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    2702                 let=let,
#    2703                 comment=comment,
# -> 2704                 **kwargs,
#    2705             )
#    2706
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2607             session,
#    2608             retryable=not cmd._performs_write,
# -> 2609             operation=_Op.AGGREGATE,
#    2610         )
#    2611
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1541             read_pref=read_pref,
#    1542             retryable=retryable,
# -> 1543             operation_id=operation_id,
#    1544         )
#    1545
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1498             address=address,
#    1499             retryable=retryable,
# -> 1500             operation_id=operation_id,
#    1501         ).run()
#    1502
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in run(self)
#    2345             self._check_last_error(check_csot=True)
#    2346             try:
# -> 2347                 return self._read() if self._is_read else self._write()
#    2348             except ServerSelectionTimeoutError:
#    2349                 # The application may think the write was never attempted
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _read(self)
#    2483             if self._retrying and not self._retryable:
#    2484                 self._check_last_error()
# -> 2485             return self._func(self._session, self._server, conn, read_pref)  # type: ignore
#    2486
#    2487
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/aggregation.py in get_cursor(self, session, server, conn, read_preference)
#     171             session=session,
#     172             client=self._database.client,
# --> 173             user_fields=self._user_fields,
#     174         )
#     175
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/helpers.py in inner(*args, **kwargs)
#     340
#     341         try:
# --> 342             return func(*args, **kwargs)
#     343         except OperationFailure as exc:
#     344             if no_reauth:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1014         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#    1015         except BaseException as error:
# -> 1016             self._raise_connection_failure(error)
#    1017
#    1018     def send_message(self, message: bytes, max_doc_size: int) -> None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1008                 user_fields=user_fields,
#    1009                 exhaust_allowed=exhaust_allowed,
# -> 1010                 write_concern=write_concern,
#    1011             )
#    1012         except (OperationFailure, NotPrimaryError):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     200             response_doc: _DocumentOut = {"ok": 1}
#     201         else:
# --> 202             reply = receive_message(conn, request_id)
#     203             conn.more_to_come = reply.more_to_come
#     204             unpacked_docs = reply.unpack_response(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in receive_message(conn, request_id, max_message_size)
#     315             deadline = None
#     316     # Ignore the response's request id.
# --> 317     length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     318     # No request_id for exhaust cursor "getMore".
#     319     if request_id is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(conn, length, deadline)
#     392     while bytes_read < length:
#     393         try:
# --> 394             wait_for_read(conn, deadline)
#     395             # CSOT: Update timeout. When the timeout has expired perform one
#     396             # final non-blocking recv. This helps avoid spurious timeouts when
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in wait_for_read(conn, deadline)
#     373             else:
#     374                 timeout = _POLL_TIMEOUT
# --> 375             readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376         if conn.cancel_context.cancelled:
#     377             raise _OperationCancelled("operation cancelled")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/socket_checker.py in select(self, sock, read, write, timeout)
#      64                         # timeout is in seconds.
#      65                         timeout_ = None if timeout is None else timeout * 1000
# ---> 66                         res = self._poller.poll(timeout_)
#      67                         # poll returns a possibly-empty list containing
#      68                         # (fd, event) 2-tuples for the descriptors that have
#
# KeyboardInterrupt:

# %%
pipeline = [
    # 1. Join with the business collection to get each review’s city
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    # 2. Unwind the joined array
    { "$unwind": "$business_info" },

    # 3. Group by user, collecting the set of cities they’ve reviewed in
    {
        "$group": {
            "_id": "$user_id",
            "uniqueCities": { "$addToSet": "$business_info.city" }
        }
    },
    # 4. Compute the number of distinct cities per user
    {
        "$addFields": {
            "cityCount": { "$size": "$uniqueCities" }
        }
    },
    # 5. Keep only those with three or more distinct cities
    {
        "$match": {
            "cityCount": { "$gte": 3 }
        }
    },
    # 6. Order by how many cities, descending
    { "$sort": { "cityCount": -1 } },
    # 7. Limit to the top 10 users
    { "$limit": 10 }
]

results = list(db.review.aggregate(pipeline))
print("Users Who Reviewed in 3+ Cities (MongoDB):")
pprint.pprint(results)
for row in results:
    print(f"Number of results: {len(results)}")
    print(row)

# %%
# Enable profiling for all operations
db.command("profile", 2)

# Run aggregation query
pipeline = [
    # 1. Join with the business collection to get each review’s city
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    # 2. Unwind the joined array
    { "$unwind": "$business_info" },

    # 3. Group by user, collecting the set of cities they’ve reviewed in
    {
        "$group": {
            "_id": "$user_id",
            "uniqueCities": { "$addToSet": "$business_info.city" }
        }
    },
    # 4. Compute the number of distinct cities per user
    {
        "$addFields": {
            "cityCount": { "$size": "$uniqueCities" }
        }
    },
    # 5. Keep only those with three or more distinct cities
    {
        "$match": {
            "cityCount": { "$gte": 3 }
        }
    },
    # 6. Order by how many cities, descending
    { "$sort": { "cityCount": -1 } },
    # 7. Limit to the top 10 users
    { "$limit": 10 }
]

results = list(db.review.aggregate(pipeline))

# Optional delay to ensure profiling is logged
time.sleep(1)

# Fetch latest profiling info
profile = db["system.profile"].find(
    {"ns": "yelp.review", "op": "command", "command.aggregate": "review"}
).sort("ts", -1).limit(1)

# Show profiling result
for doc in profile:
    pprint.pprint(doc)

# Turn off profiling to avoid overhead
db.command("profile", 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l_/qqmwldsd40dccgp2bsqp6cx00000gn/T/ipykernel_68082/2667831402.py in <module>
#      41 ]
#      42
# ---> 43 results = list(db.review.aggregate(pipeline))
#      44
#      45 # Optional delay to ensure profiling is logged
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    2702                 let=let,
#    2703                 comment=comment,
# -> 2704                 **kwargs,
#    2705             )
#    2706
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2607             session,
#    2608             retryable=not cmd._performs_write,
# -> 2609             operation=_Op.AGGREGATE,
#    2610         )
#    2611
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1541             read_pref=read_pref,
#    1542             retryable=retryable,
# -> 1543             operation_id=operation_id,
#    1544         )
#    1545
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1498             address=address,
#    1499             retryable=retryable,
# -> 1500             operation_id=operation_id,
#    1501         ).run()
#    1502
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in run(self)
#    2345             self._check_last_error(check_csot=True)
#    2346             try:
# -> 2347                 return self._read() if self._is_read else self._write()
#    2348             except ServerSelectionTimeoutError:
#    2349                 # The application may think the write was never attempted
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _read(self)
#    2483             if self._retrying and not self._retryable:
#    2484                 self._check_last_error()
# -> 2485             return self._func(self._session, self._server, conn, read_pref)  # type: ignore
#    2486
#    2487
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/aggregation.py in get_cursor(self, session, server, conn, read_preference)
#     171             session=session,
#     172             client=self._database.client,
# --> 173             user_fields=self._user_fields,
#     174         )
#     175
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/helpers.py in inner(*args, **kwargs)
#     340
#     341         try:
# --> 342             return func(*args, **kwargs)
#     343         except OperationFailure as exc:
#     344             if no_reauth:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1014         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#    1015         except BaseException as error:
# -> 1016             self._raise_connection_failure(error)
#    1017
#    1018     def send_message(self, message: bytes, max_doc_size: int) -> None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1008                 user_fields=user_fields,
#    1009                 exhaust_allowed=exhaust_allowed,
# -> 1010                 write_concern=write_concern,
#    1011             )
#    1012         except (OperationFailure, NotPrimaryError):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     200             response_doc: _DocumentOut = {"ok": 1}
#     201         else:
# --> 202             reply = receive_message(conn, request_id)
#     203             conn.more_to_come = reply.more_to_come
#     204             unpacked_docs = reply.unpack_response(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in receive_message(conn, request_id, max_message_size)
#     315             deadline = None
#     316     # Ignore the response's request id.
# --> 317     length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     318     # No request_id for exhaust cursor "getMore".
#     319     if request_id is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(conn, length, deadline)
#     392     while bytes_read < length:
#     393         try:
# --> 394             wait_for_read(conn, deadline)
#     395             # CSOT: Update timeout. When the timeout has expired perform one
#     396             # final non-blocking recv. This helps avoid spurious timeouts when
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in wait_for_read(conn, deadline)
#     373             else:
#     374                 timeout = _POLL_TIMEOUT
# --> 375             readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376         if conn.cancel_context.cancelled:
#     377             raise _OperationCancelled("operation cancelled")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/socket_checker.py in select(self, sock, read, write, timeout)
#      64                         # timeout is in seconds.
#      65                         timeout_ = None if timeout is None else timeout * 1000
# ---> 66                         res = self._poller.poll(timeout_)
#      67                         # poll returns a possibly-empty list containing
#      68                         # (fd, event) 2-tuples for the descriptors that have
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4. Businesses reviewed in 2018 but NOT reviewed in 2019–2020

# %% [markdown]
# #### SQL

# %%
cur.execute("""
SELECT DISTINCT b.business_id, b.name
FROM business b
JOIN review r1 ON b.business_id = r1.business_id
WHERE EXTRACT(YEAR FROM r1.date) = 2018
AND b.business_id NOT IN (
    SELECT DISTINCT r2.business_id
    FROM review r2
    WHERE EXTRACT(YEAR FROM r2.date) IN (2019, 2020)
)
LIMIT 10;
""")

results = cur.fetchall()
print("Businesses Active in 2018 But Inactive 2019–2020:")
for row in results:
    print(row)
# Out:
# Businesses Active in 2018 But Inactive 2019–2020:
# ('_2FrIA5unwbbweldUnpROQ', "Sip N' Cycle")
# ('_jC2Qwq9yH4Lv5lyfyqBXA', 'Avenue of the Arts Dental')
# ('_jcvEAM75TohIesGW6iLWw', 'Viking Pastries')
# ('_L48f6NzAWnJKOBoxs2KOw', 'Bronco Elite')
# ('_Ld026NfDcxSh8NEQPkxpw', 'St  Louis Bread')
# ('_mwfGrkuU1Fwemt5m-lrEA', "Soprano's Meat Market")
# ('_O-FP2AkGgzvndJ6UqzkxA', 'Kingston Martinez & Hogan')
# ('_OB65sIprNs4eUm1SHjhxw', 'Lasaters Coffee and Tea - Nashville')
# ('_OxtWf7PXv3O_IbveYk9oQ', 'La Garrafa')
# ('_tdjQfnrT1k4dNjSbSXotg', 'Nu-Temp Heating & Cooling')

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT DISTINCT b.business_id, b.name
FROM business b
JOIN review r1 ON b.business_id = r1.business_id
WHERE EXTRACT(YEAR FROM r1.date) = 2018
AND b.business_id NOT IN (
    SELECT DISTINCT r2.business_id
    FROM review r2
    WHERE EXTRACT(YEAR FROM r2.date) IN (2019, 2020)
);
""")

plan = cur.fetchall()
print("Execution Plan for usinesses Active in 2018 But Inactive 2019–2020:")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for usinesses Active in 2018 But Inactive 2019–2020:
# Unique  (cost=125252.67..125265.52 rows=1713 width=42) (actual time=271.362..272.205 rows=1047 loops=1)
#   ->  Sort  (cost=125252.67..125256.96 rows=1713 width=42) (actual time=271.361..271.995 rows=3043 loops=1)
#         Sort Key: b.business_id, b.name
#         Sort Method: quicksort  Memory: 281kB
#         ->  Hash Join  (cost=64334.08..125160.67 rows=1713 width=42) (actual time=199.306..270.560 rows=3043 loops=1)
#               Hash Cond: (r1.business_id = b.business_id)
#               ->  Gather  (cost=1000.00..61817.59 rows=3426 width=32) (actual time=0.102..63.830 rows=89367 loops=1)
#                     Workers Planned: 2
#                     Workers Launched: 2
#                     ->  Parallel Seq Scan on review r1  (cost=0.00..60474.99 rows=1428 width=32) (actual time=0.336..82.554 rows=29789 loops=3)
#                           Filter: (EXTRACT(year FROM date) = '2018'::numeric)
#                           Rows Removed by Filter: 198637
#               ->  Hash  (cost=63240.33..63240.33 rows=7500 width=42) (actual time=199.193..199.206 rows=3405 loops=1)
#                     Buckets: 8192  Batches: 1  Memory Usage: 312kB
#                     ->  Seq Scan on business b  (cost=61700.83..63240.33 rows=7500 width=42) (actual time=155.674..198.642 rows=3405 loops=1)
#                           Filter: (NOT (ANY (business_id = (hashed SubPlan 1).col1)))
#                           Rows Removed by Filter: 11595
#                           SubPlan 1
#                             ->  Unique  (cost=61638.88..61700.33 rows=200 width=32) (actual time=144.588..153.918 rows=11595 loops=1)
#                                   ->  Gather Merge  (cost=61638.88..61699.33 rows=400 width=32) (actual time=144.587..152.527 rows=26668 loops=1)
#                                         Workers Planned: 2
#                                         Workers Launched: 2
#                                         ->  Unique  (cost=60638.86..60653.14 rows=200 width=32) (actual time=128.067..133.637 rows=8889 loops=3)
#                                               ->  Sort  (cost=60638.86..60646.00 rows=2855 width=32) (actual time=128.066..129.667 rows=48641 loops=3)
#                                                     Sort Key: r2.business_id
#                                                     Sort Method: quicksort  Memory: 1537kB
#                                                     Worker 0:  Sort Method: quicksort  Memory: 1537kB
#                                                     Worker 1:  Sort Method: quicksort  Memory: 1537kB
#                                                     ->  Parallel Seq Scan on review r2  (cost=0.00..60474.99 rows=2855 width=32) (actual time=1.563..107.089 rows=48641 loops=3)
#                                                           Filter: (EXTRACT(year FROM date) = ANY ('{2019,2020}'::numeric[]))
#                                                           Rows Removed by Filter: 179785
# Planning Time: 0.178 ms
# Execution Time: 272.622 ms

# %% [markdown]
# #### MQL

# %%
pipeline = [
    # 1. Join with the business collection to get business details
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    # 2. Unwind the joined array
    { "$unwind": "$business_info" },

    # 3. Project the business ID, name, and extract review year
    {
        "$project": {
            "business_id": 1,
            "business_name": "$business_info.name",
            "reviewYear": { "$year": { "$toDate": "$date" } }
        }
    },
    # 4. Group by business, collecting all years the business was reviewed
    {
        "$group": {
            "_id": {
                "business_id": "$business_id",
                "business_name": "$business_name"
            },
            "yearsReviewed": { "$addToSet": "$reviewYear" }
        }
    },
    # 5. Keep only businesses reviewed in 2018 but NOT in 2019 or 2020
    {
        "$match": {
            "yearsReviewed": {
                "$all": [2018],
                "$nin": [2019, 2020]
            }
        }
    },
    # 6. Sort by business_id ascending
    { "$sort": { "_id.business_id": 1 } },

    # 7. Limit to the top 10 businesses
    { "$limit": 10 }
]

results = list(db.review.aggregate(pipeline))
print("Businesses reviewed in 2018 but NOT reviewed in 2019–2020 (MongoDB):")
pprint.pprint(results)
print(f"Number of results: {len(results)}")
for row in results:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l_/qqmwldsd40dccgp2bsqp6cx00000gn/T/ipykernel_68082/1867785899.py in <module>
#      46 ]
#      47
# ---> 48 results = list(db.review.aggregate(pipeline))
#      49 print("Businesses reviewed in 2018 but NOT reviewed in 2019–2020 (MongoDB):")
#      50 pprint.pprint(results)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    2702                 let=let,
#    2703                 comment=comment,
# -> 2704                 **kwargs,
#    2705             )
#    2706
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2607             session,
#    2608             retryable=not cmd._performs_write,
# -> 2609             operation=_Op.AGGREGATE,
#    2610         )
#    2611
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1541             read_pref=read_pref,
#    1542             retryable=retryable,
# -> 1543             operation_id=operation_id,
#    1544         )
#    1545
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1498             address=address,
#    1499             retryable=retryable,
# -> 1500             operation_id=operation_id,
#    1501         ).run()
#    1502
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in run(self)
#    2345             self._check_last_error(check_csot=True)
#    2346             try:
# -> 2347                 return self._read() if self._is_read else self._write()
#    2348             except ServerSelectionTimeoutError:
#    2349                 # The application may think the write was never attempted
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _read(self)
#    2483             if self._retrying and not self._retryable:
#    2484                 self._check_last_error()
# -> 2485             return self._func(self._session, self._server, conn, read_pref)  # type: ignore
#    2486
#    2487
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/aggregation.py in get_cursor(self, session, server, conn, read_preference)
#     171             session=session,
#     172             client=self._database.client,
# --> 173             user_fields=self._user_fields,
#     174         )
#     175
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/helpers.py in inner(*args, **kwargs)
#     340
#     341         try:
# --> 342             return func(*args, **kwargs)
#     343         except OperationFailure as exc:
#     344             if no_reauth:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1014         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#    1015         except BaseException as error:
# -> 1016             self._raise_connection_failure(error)
#    1017
#    1018     def send_message(self, message: bytes, max_doc_size: int) -> None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1008                 user_fields=user_fields,
#    1009                 exhaust_allowed=exhaust_allowed,
# -> 1010                 write_concern=write_concern,
#    1011             )
#    1012         except (OperationFailure, NotPrimaryError):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     200             response_doc: _DocumentOut = {"ok": 1}
#     201         else:
# --> 202             reply = receive_message(conn, request_id)
#     203             conn.more_to_come = reply.more_to_come
#     204             unpacked_docs = reply.unpack_response(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in receive_message(conn, request_id, max_message_size)
#     315             deadline = None
#     316     # Ignore the response's request id.
# --> 317     length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     318     # No request_id for exhaust cursor "getMore".
#     319     if request_id is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(conn, length, deadline)
#     392     while bytes_read < length:
#     393         try:
# --> 394             wait_for_read(conn, deadline)
#     395             # CSOT: Update timeout. When the timeout has expired perform one
#     396             # final non-blocking recv. This helps avoid spurious timeouts when
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in wait_for_read(conn, deadline)
#     373             else:
#     374                 timeout = _POLL_TIMEOUT
# --> 375             readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376         if conn.cancel_context.cancelled:
#     377             raise _OperationCancelled("operation cancelled")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/socket_checker.py in select(self, sock, read, write, timeout)
#      64                         # timeout is in seconds.
#      65                         timeout_ = None if timeout is None else timeout * 1000
# ---> 66                         res = self._poller.poll(timeout_)
#      67                         # poll returns a possibly-empty list containing
#      68                         # (fd, event) 2-tuples for the descriptors that have
#
# KeyboardInterrupt:

# %%
# Enable profiling for all operations
db.command("profile", 2)

# Run aggregation query
pipeline = [
    # 1. Join with the business collection to get business details
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    # 2. Unwind the joined array
    { "$unwind": "$business_info" },

    # 3. Project the business ID, name, and extract review year
    {
        "$project": {
            "business_id": 1,
            "business_name": "$business_info.name",
            "reviewYear": { "$year": { "$toDate": "$date" } }
        }
    },
    # 4. Group by business, collecting all years the business was reviewed
    {
        "$group": {
            "_id": {
                "business_id": "$business_id",
                "business_name": "$business_name"
            },
            "yearsReviewed": { "$addToSet": "$reviewYear" }
        }
    },
    # 5. Keep only businesses reviewed in 2018 but NOT in 2019 or 2020
    {
        "$match": {
            "yearsReviewed": {
                "$all": [2018],
                "$nin": [2019, 2020]
            }
        }
    },
    # 6. Sort by business_id ascending
    { "$sort": { "_id.business_id": 1 } },

    # 7. Limit to the top 10 businesses
    { "$limit": 10 }
]

results = list(db.review.aggregate(pipeline))

# Optional delay to ensure profiling is logged
time.sleep(1)

# Fetch latest profiling info
profile = db["system.profile"].find(
    {"ns": "yelp.review", "op": "command", "command.aggregate": "review"}
).sort("ts", -1).limit(1)

# Show profiling result
for doc in profile:
    pprint.pprint(doc)

# Turn off profiling to avoid overhead
db.command("profile", 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l_/qqmwldsd40dccgp2bsqp6cx00000gn/T/ipykernel_68082/3115410536.py in <module>
#      50 ]
#      51
# ---> 52 results = list(db.review.aggregate(pipeline))
#      53
#      54 # Optional delay to ensure profiling is logged
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    2702                 let=let,
#    2703                 comment=comment,
# -> 2704                 **kwargs,
#    2705             )
#    2706
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2607             session,
#    2608             retryable=not cmd._performs_write,
# -> 2609             operation=_Op.AGGREGATE,
#    2610         )
#    2611
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1541             read_pref=read_pref,
#    1542             retryable=retryable,
# -> 1543             operation_id=operation_id,
#    1544         )
#    1545
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1498             address=address,
#    1499             retryable=retryable,
# -> 1500             operation_id=operation_id,
#    1501         ).run()
#    1502
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in run(self)
#    2345             self._check_last_error(check_csot=True)
#    2346             try:
# -> 2347                 return self._read() if self._is_read else self._write()
#    2348             except ServerSelectionTimeoutError:
#    2349                 # The application may think the write was never attempted
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _read(self)
#    2483             if self._retrying and not self._retryable:
#    2484                 self._check_last_error()
# -> 2485             return self._func(self._session, self._server, conn, read_pref)  # type: ignore
#    2486
#    2487
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/aggregation.py in get_cursor(self, session, server, conn, read_preference)
#     171             session=session,
#     172             client=self._database.client,
# --> 173             user_fields=self._user_fields,
#     174         )
#     175
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/helpers.py in inner(*args, **kwargs)
#     340
#     341         try:
# --> 342             return func(*args, **kwargs)
#     343         except OperationFailure as exc:
#     344             if no_reauth:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1014         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#    1015         except BaseException as error:
# -> 1016             self._raise_connection_failure(error)
#    1017
#    1018     def send_message(self, message: bytes, max_doc_size: int) -> None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1008                 user_fields=user_fields,
#    1009                 exhaust_allowed=exhaust_allowed,
# -> 1010                 write_concern=write_concern,
#    1011             )
#    1012         except (OperationFailure, NotPrimaryError):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     200             response_doc: _DocumentOut = {"ok": 1}
#     201         else:
# --> 202             reply = receive_message(conn, request_id)
#     203             conn.more_to_come = reply.more_to_come
#     204             unpacked_docs = reply.unpack_response(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in receive_message(conn, request_id, max_message_size)
#     315             deadline = None
#     316     # Ignore the response's request id.
# --> 317     length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     318     # No request_id for exhaust cursor "getMore".
#     319     if request_id is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(conn, length, deadline)
#     392     while bytes_read < length:
#     393         try:
# --> 394             wait_for_read(conn, deadline)
#     395             # CSOT: Update timeout. When the timeout has expired perform one
#     396             # final non-blocking recv. This helps avoid spurious timeouts when
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/network.py in wait_for_read(conn, deadline)
#     373             else:
#     374                 timeout = _POLL_TIMEOUT
# --> 375             readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376         if conn.cancel_context.cancelled:
#     377             raise _OperationCancelled("operation cancelled")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/socket_checker.py in select(self, sock, read, write, timeout)
#      64                         # timeout is in seconds.
#      65                         timeout_ = None if timeout is None else timeout * 1000
# ---> 66                         res = self._poller.poll(timeout_)
#      67                         # poll returns a possibly-empty list containing
#      68                         # (fd, event) 2-tuples for the descriptors that have
#
# KeyboardInterrupt:

# %% [markdown]
# ### 5. Most reviewed business in each city

# %%
cur.execute("""

SELECT DISTINCT ON (b.city) b.city, b.name, b.review_count
FROM business b
ORDER BY b.city, b.review_count DESC
LIMIT 10;
""")

results = cur.fetchall()
print("Most Reviewed Business Per City:")
for row in results:
    print(row)
# Out:
# Most Reviewed Business Per City:
# ('AB Edmonton', 'Ricci Hair Company', 6)
# ('abington', 'D D Daughters Lace Wig Beautique', 5)
# ('Abington', 'Kitchen Bar', 377)
# ('Abington Township', 'Iron Hill Brewery & Restaurant', 223)
# ('Affton', 'Sushi Hana', 141)
# ('Afton', '9 Mile Garden', 50)
# ('Alberta Park Industrial', 'Crosstown Autobody', 5)
# ('Aldan', 'Penn Pines Diner', 48)
# ('Algiers', "Domino's Pizza", 28)
# ('Aliso Viejo', 'Carolyn Rife Photography', 9)

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT DISTINCT ON (b.city) b.city, b.name, b.review_count
FROM business b
ORDER BY b.city, b.review_count DESC;
""")

plan = cur.fetchall()
print("Execution Plan for Most Reviewed Business Per City:")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for Most Reviewed Business Per City:
# Unique  (cost=31928.16..32679.89 rows=780 width=34) (actual time=226.329..251.199 rows=1416 loops=1)
#   ->  Sort  (cost=31928.16..32304.02 rows=150346 width=34) (actual time=226.328..245.726 rows=150346 loops=1)
#         Sort Key: city, review_count DESC
#         Sort Method: external merge  Disk: 6744kB
#         ->  Seq Scan on business b  (cost=0.00..14887.46 rows=150346 width=34) (actual time=0.060..65.896 rows=150346 loops=1)
# Planning Time: 0.163 ms
# Execution Time: 257.989 ms

# %% [markdown]
# #### MQL

# %%
pipeline = [
    # 1. Join with the business collection to get city info
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    # 2. Unwind the joined array
    { "$unwind": "$business_info" },
    # 3. Group by city and business_id to count number of reviews per business per city
    {
        "$group": {
            "_id": {
                "city": "$business_info.city",
                "business_id": "$business_id"
            },
            "review_count": { "$sum": 1 }
        }
    },
    # 4. Sort by city and review count descending
    {
        "$sort": {
            "_id.city": 1,
            "review_count": -1
        }
    },
    # 5. For each city, pick the business with the highest review count
    {
        "$group": {
            "_id": "$_id.city",
            "business_id": { "$first": "$_id.business_id" },
            "review_count": { "$first": "$review_count" }
        }
    },
    # 6. Optional: Rename fields for clarity
    {
        "$project": {
            "city": "$_id",
            "business_id": 1,
            "review_count": 1,
            "_id": 0
        }
    }
]

results = list(db.review.aggregate(pipeline))
print("Most Reviewed Business in Each City (MongoDB):")
print(f"Number of results: {len(results)}")
for row in results:
    print(row)
# Out:
# Most Reviewed Business in Each City (MongoDB):
# Number of results: 632
# {'business_id': 'QXlQzuc_LIfln_lG0Nm4PA', 'review_count': 7, 'city': 'Bargersville'}
# {'business_id': 'NdgNF6Bpk1nLAcKg_j_r9w', 'review_count': 11, 'city': 'Dupo'}
# {'business_id': 'OZK2JhyPVY1g8vlzOQVxfw', 'review_count': 15, 'city': 'Perkiomenville'}
# {'business_id': 'RrO7r9nTQ-7-TifyxMv6KQ', 'review_count': 9, 'city': 'Whiteland'}
# {'business_id': 'tMZysJlRjlbMy9qWZuuPLA', 'review_count': 27, 'city': 'Quakertown'}
# {'business_id': 's6-pwQHhvnyeMmyhROvvgA', 'review_count': 46, 'city': 'Real Goleta'}
# {'business_id': 'tV46IhCfHbsx_af-pMupiw', 'review_count': 1331, 'city': 'Tucson'}
# {'business_id': 'CJqI1oDfaq_dtABzk1JYHg', 'review_count': 13, 'city': 'Overbrook'}
# {'business_id': 'eiStH9DM4qGRlZDZrn3__Q', 'review_count': 45, 'city': 'Saint Ann'}
# {'business_id': '6wVGdVcFA8yPuWer_hvB9g', 'review_count': 11, 'city': 'Merion Station'}
# {'business_id': 'wnucEo99Xv80lLKLybkq3w', 'review_count': 53, 'city': 'Pipersville'}
# {'business_id': 'N4IFNpTn7kKfK9akJkerwQ', 'review_count': 522, 'city': 'Saint Petersburg'}
# {'business_id': 'HTgKfmmlzgE43trhntv8-w', 'review_count': 537, 'city': 'Elkins Park'}
# {'business_id': '5ln4ESCi6mnfTBx4bYr4dw', 'review_count': 642, 'city': 'St Pete Beach'}
# {'business_id': '-I6kYJze5to1AISg9i30-w', 'review_count': 102, 'city': 'Concordville'}
# {'business_id': 'c1OIy38WfCeAd3LNeAoC6A', 'review_count': 22, 'city': 'Drexel Hil'}
# {'business_id': '1lVORLOmRYIEKVSpehlGBg', 'review_count': 50, 'city': 'St. Ann'}
# {'business_id': 'rj2PL-1BWwaE49jvUD5W8Q', 'review_count': 13, 'city': 'Trappe'}
# {'business_id': 'Jc3UuJS-6N1FGLX46145tg', 'review_count': 8, 'city': 'West Deptford Townsh'}
# {'business_id': 'cBiHULO8B4gTEav8eQJhuQ', 'review_count': 440, 'city': 'Cherry Hill'}
# {'business_id': 'iuhZSdAQqDs4kYh7rHjXZg', 'review_count': 28, 'city': 'Ladue'}
# {'business_id': '49AD6Oddkfd4KNVrufoM6g', 'review_count': 26, 'city': 'Sun Valley'}
# {'business_id': '5KOA44JsSjIyzOzJAp8d5w', 'review_count': 7, 'city': 'Town & Country'}
# {'business_id': 'bV5raFcGwmElIbX9G_rWOQ', 'review_count': 59, 'city': 'Upper Pottsgrove'}
# {'business_id': 'rDr7zhYBOmC3NzJXcZd1BQ', 'review_count': 140, 'city': 'West Trenton'}
# {'business_id': 'MzWirM9CaF2Rh5pkbYgKIw', 'review_count': 22, 'city': 'Holland'}
# {'business_id': '_vpIEol9cEn3Y3KLpwbGkg', 'review_count': 288, 'city': 'Wilmington'}
# {'business_id': 'E7HZ2DeTvqVC8IrssqtOLw', 'review_count': 7, 'city': 'Gibbstown'}
# {'business_id': '4e0AuvnWvjr2cJEaEdrtxA', 'review_count': 69, 'city': 'Granite City'}
# {'business_id': 'kQoIYrwicWVN4ASBVGXJKw', 'review_count': 27, 'city': 'Prospect Park'}
# {'business_id': '70a-DEnbsZiYIjMaXnO8rQ', 'review_count': 6, 'city': 'Wilmington '}
# {'business_id': 'MXP-VKFJYlu840ClSjxNSg', 'review_count': 50, 'city': 'Valrico'}
# {'business_id': 'F0XiRcSbcLF4GwA2A2TDKQ', 'review_count': 273, 'city': 'Edmonton'}
# {'business_id': 'FrKhPnv38j2tjGBvBWBPyQ', 'review_count': 102, 'city': 'Gilbertsville'}
# {'business_id': 'leCOue2vK75YBrztlPQM3Q', 'review_count': 8, 'city': 'wesley chapel'}
# {'business_id': 'onp9X_9RRAEzA-yqdiSOcA', 'review_count': 638, 'city': 'Cinnaminson'}
# {'business_id': 'bpx0pcXxPjX2Mk7dDPLIxw', 'review_count': 163, 'city': 'Collegeville'}
# {'business_id': 'LW3QmxHnFLFnZN7qkVLa1Q', 'review_count': 96, 'city': 'Marana'}
# {'business_id': '7DfpkQT2ozh8UHssqBY31Q', 'review_count': 43, 'city': 'Spring House'}
# {'business_id': 'rKmGMZfuJFopDcV0gZ9jkg', 'review_count': 43, 'city': 'Furlong'}
# {'business_id': 'EbRp29tSca4DpB9NM6N1SA', 'review_count': 28, 'city': 'Whitestown'}
# {'business_id': '5XtuUFM1f1hIehVd9SbYSg', 'review_count': 7, 'city': 'Drexel Heights'}
# {'business_id': 'NKOFsaRPhIlNpQf8z6SStQ', 'review_count': 24, 'city': 'Mississauga'}
# {'business_id': '3P-5sAQoAyKcoO5e4paG7Q', 'review_count': 47, 'city': 'New Castle'}
# {'business_id': 'K3rQIh4EXBwCb1xass2k7g', 'review_count': 90, 'city': 'Somerdale'}
# {'business_id': 'EN93aHUaowPXDXXv01PTZw', 'review_count': 9, 'city': 'Ewing Twp'}
# {'business_id': 'y5iNMvsjCykcKLYmcBLXPg', 'review_count': 5, 'city': 'South County'}
# {'business_id': '-o6bah2j6_IH9pkwANXcLA', 'review_count': 251, 'city': 'Palm Harbor'}
# {'business_id': 'UOzygOSJxEmfPVzNWc4qNA', 'review_count': 15, 'city': 'Penndel'}
# {'business_id': 'XaSNISuTB4DKvzS3Rug5Nw', 'review_count': 60, 'city': 'Flourtown'}
# {'business_id': 'g2rtbtmL_MTf_cjATokalw', 'review_count': 12, 'city': 'Boothwyn'}
# {'business_id': 'tQRwoBkWImFYNFkv-gMXpQ', 'review_count': 68, 'city': 'Drexel Hill'}
# {'business_id': 'ogeBHp2egBL92cTqbPX4Pw', 'review_count': 13, 'city': 'Atco'}
# {'business_id': '7O6ee_91pqe67cdAjAXK2g', 'review_count': 20, 'city': 'Riverside'}
# {'business_id': 'af-NNvU2peWeF9VWtd5anA', 'review_count': 12, 'city': 'Waterford Works'}
# {'business_id': 'Z1oLGCFvhLpJ8jl4CazlTQ', 'review_count': 103, 'city': 'Pennsauken'}
# {'business_id': 'dDB7tPluGntO43KT_aoLDA', 'review_count': 40, 'city': 'Zephyrhills'}
# {'business_id': 'jDW4w0kICxhWEfgsy0n-YA', 'review_count': 51, 'city': 'Fairmont City'}
# {'business_id': '_bXtF8hXJgEcUMQIOfqSsw', 'review_count': 81, 'city': 'Harleysville'}
# {'business_id': '6CTLWfcs_dVk0-tXz2Mgnw', 'review_count': 36, 'city': 'St. Albert'}
# {'business_id': 'zuJmP1Uh8txOpGdwzZDOiQ', 'review_count': 64, 'city': 'Ewing Township'}
# {'business_id': '5Z7VyIlPYa3SFHkG2PG6DQ', 'review_count': 35, 'city': 'Creve Couer'}
# {'business_id': 'BTjGskjD0xDKT2L-jcuOGA', 'review_count': 62, 'city': 'Montgomeryville'}
# {'business_id': '_FRC6kmF_6-5cPwYOv5dZg', 'review_count': 482, 'city': 'Franklin'}
# {'business_id': 'MxbdVt4x3F1OCZA93PKdiw', 'review_count': 91, 'city': 'Wood River'}
# {'business_id': '6CC0qV5ZDGkp1ljrtNChEw', 'review_count': 33, 'city': 'Yeadon'}
# {'business_id': 'u_s0aB2avO4UJNm7lZ1JEw', 'review_count': 12, 'city': 'Florence'}
# {'business_id': 'IH8_zFDyFDA2RXwUX2CC0w', 'review_count': 16, 'city': 'Harrison Township'}
# {'business_id': 'JcVEMcSdNJA-qJClXqsTqA', 'review_count': 122, 'city': 'Newtown Square'}
# {'business_id': 'w2zIGxepq2yU5vMWbNyQYg', 'review_count': 19, 'city': 'Buckingham Township'}
# {'business_id': 'h2nBTqJVHAyltyeq7sZZ-w', 'review_count': 247, 'city': 'Mullica Hill'}
# {'business_id': '5jSFN8r7H4a0lPOv8tfcRg', 'review_count': 9, 'city': 'Pilgrim Gardens'}
# {'business_id': 'U7ON-atDF3vTpSzTgnTYyA', 'review_count': 152, 'city': 'Yardley'}
# {'business_id': 'W9qOmVBNeeiYTFUfoRsErg', 'review_count': 48, 'city': 'Garden City'}
# {'business_id': 'hHzKMfJe7uuw_7WIEHEwBQ', 'review_count': 296, 'city': 'Indian Rocks Beach'}
# {'business_id': 'BjD-RwoHBV8AjtErZKpE1Q', 'review_count': 11, 'city': 'Donelson'}
# {'business_id': 'hTA0eCoMdAebXzm4jkx-0A', 'review_count': 448, 'city': 'Madeira Beach'}
# {'business_id': 'snY4Z9Tg-aOvAM3B59TVEw', 'review_count': 8, 'city': 'Sharon Hill'}
# {'business_id': '7119UBDxs6ugvitzkJ0prw', 'review_count': 5, 'city': 'Berlin Township'}
# {'business_id': 'OWOOc0YjU_kioLeEgo5VCA', 'review_count': 2480, 'city': 'Nashville'}
# {'business_id': 'LVWgnIor8mzfqtR__R3XsQ', 'review_count': 16, 'city': 'Breckenridge Hills'}
# {'business_id': 'Nl8lPfJalOiX9rJiibD8jw', 'review_count': 50, 'city': 'Mount Holly'}
# {'business_id': 'bcmzg1y1smYIe1i-tvEKFQ', 'review_count': 13, 'city': 'Fairview'}
# {'business_id': 'sKl0EzbH76zZL5CFLpdrgA', 'review_count': 61, 'city': 'Odessa'}
# {'business_id': 'ZWypnFg10-MSYw54w_CPsA', 'review_count': 5, 'city': 'Fountainville'}
# {'business_id': 'RO1LyRwH2eZT_eNUN0dC3w', 'review_count': 155, 'city': 'Newark'}
# {'business_id': 'SaZJPDpHKl57z3giyPcleg', 'review_count': 10, 'city': 'Hartford'}
# {'business_id': 'TV58NdbRgHq2IMxyzHWDbQ', 'review_count': 194, 'city': 'Mt. Juliet'}
# {'business_id': '-GFJfMFzOi1p0QS_1QiIIA', 'review_count': 12, 'city': 'Arabi'}
# {'business_id': 'm_12lKiQ1EkdwRN3ufKs2A', 'review_count': 471, 'city': 'Eagle'}
# {'business_id': 'GVWcwqUD-ekCMQ0x2Ke6Ww', 'review_count': 823, 'city': 'Tampa'}
# {'business_id': 'gjSygHjeDCDCPsCdFiyW3Q', 'review_count': 65, 'city': 'Lumberton'}
# {'business_id': 'TD9NLum024l83vrsGFYFkQ', 'review_count': 57, 'city': 'Burlington'}
# {'business_id': 'GXqzvoBm9iEZ_R6Ubeqzrw', 'review_count': 207, 'city': 'Langhorne'}
# {'business_id': 'Y-UcxAJlx8exuOJARQ4VVQ', 'review_count': 8, 'city': 'Collingdale'}
# {'business_id': 'Y6K9DT44-4Md-ycMkC0nLg', 'review_count': 185, 'city': 'Colmar'}
# {'business_id': 'AmJmSDaiDmPT0tUw2iVe1A', 'review_count': 32, 'city': 'Shade'}
# {'business_id': 'fTQs7fBggnYlKGbujXw76w', 'review_count': 112, 'city': 'Plymouth Meeting'}
# {'business_id': '6PEM9QysQrUjJks9Rm7lng', 'review_count': 108, 'city': 'Mount Juliet'}
# {'business_id': '6TPlb2eRasW6R0Fzz6T_JQ', 'review_count': 75, 'city': 'Radnor'}
# {'business_id': 'foX_wHlX09MbkzVX_J7QiA', 'review_count': 60, 'city': 'Maran'}
# {'business_id': '3XXt0s_SDC9SyFTiIPNSgA', 'review_count': 398, 'city': 'St. Louis'}
# {'business_id': 'yzzAJll9uYnfxy5BUwGpTw', 'review_count': 6, 'city': 'Palm Harbor, FL'}
# {'business_id': 'g2hkkxwC2llfR-eYr0HPvQ', 'review_count': 52, 'city': 'Twin Oaks'}
# {'business_id': '7I83yaco0OfOeBS9PSShvQ', 'review_count': 15, 'city': 'Frontenac'}
# {'business_id': 'fgnHM4VT-n1VjFL3YeBJsg', 'review_count': 178, 'city': 'Harahan'}
# {'business_id': 'z87J50pmTCfbiUDZufjOVw', 'review_count': 93, 'city': 'Marcus Hook'}
# {'business_id': 'hix42wBkcK995l-eDF70FQ', 'review_count': 16, 'city': 'East Saint Louis'}
# {'business_id': 'TexC8cWPqLQKjFX80LBQ4A', 'review_count': 35, 'city': 'McCordsville'}
# {'business_id': 'znNwWHjB4kBw2EeBKU4gpg', 'review_count': 5, 'city': 'Garnet Valley'}
# {'business_id': '-9Kxik9BRNkft5rPcVvSsw', 'review_count': 121, 'city': "O'Fallon"}
# {'business_id': 'MzQwSC1JAZFBpN--SqrpGw', 'review_count': 130, 'city': 'Cedars'}
# {'business_id': 'w2gys8QVC58VO5o2I0E9Rg', 'review_count': 77, 'city': 'Perkasie'}
# {'business_id': 'A5e2SU0SOAI3wJWm_YTxCA', 'review_count': 196, 'city': 'Trenton'}
# {'business_id': 'zsXYVV6p6g58xYPAd1FDBg', 'review_count': 7, 'city': 'Bellefontaine Neighbors'}
# {'business_id': 'b92a3Va0I403KTaZelSdHg', 'review_count': 24, 'city': 'Whites Creek'}
# {'business_id': 'PEdBeArjVvl2qBM9TvmXPw', 'review_count': 28, 'city': 'Algiers'}
# {'business_id': 'JUm2CnbtlOiZ8RyaYqnB7Q', 'review_count': 47, 'city': 'Wyncote'}
# {'business_id': 'qz8ANVVHdgsyxAfktFabIQ', 'review_count': 79, 'city': 'Plant City'}
# {'business_id': 'uXjKG2gSEV9JbMnhqSdx8A', 'review_count': 39, 'city': 'Manchester'}
# {'business_id': '0wTai9TZOXmZ7qrhp2e8XA', 'review_count': 27, 'city': 'Greenbrier'}
# {'business_id': 'B4JZy1PBgiO3xp8zKgwUJA', 'review_count': 203, 'city': 'Hatboro'}
# {'business_id': 'L9wEU391_zUl9eWe7RtxKQ', 'review_count': 323, 'city': 'Oro Valley'}
# {'business_id': 'my8iGnzOiOO3__WCuRRlbQ', 'review_count': 298, 'city': 'Westmont'}
# {'business_id': 'XMr7zehuaPLhYMfX7UunMg', 'review_count': 12, 'city': 'Dublin'}
# {'business_id': 'TcQagEH4haSQzvZGhzDCjA', 'review_count': 147, 'city': 'Glen Mills'}
# {'business_id': 'aerbI0ICiEMIgeSUaLEpHw', 'review_count': 66, 'city': 'Skippack'}
# {'business_id': '4mGnHfvwjE6P-vuKowHzCQ', 'review_count': 293, 'city': 'University City'}
# {'business_id': 'md1n17dYrlCxmQul8CR38g', 'review_count': 192, 'city': 'Warrington'}
# {'business_id': 'lMMlXRtgGOQutrf6LvkhHw', 'review_count': 8, 'city': 'Wyndlake Condominium'}
# {'business_id': 'hP4P9XbVPt3tI7wkueQbVw', 'review_count': 5, 'city': 'Tullytown'}
# {'business_id': 'B8n3jqzUCvVq27WfdwZCrg', 'review_count': 32, 'city': 'Frazer'}
# {'business_id': 'wikEqd3CFUH9uTmEE2zAjQ', 'review_count': 137, 'city': 'Voorhees'}
# {'business_id': 'LR6hZV2h2pJSYNnXgHTySw', 'review_count': 30, 'city': 'Pitman'}
# {'business_id': 'KxgoNsTwdurBn7gkIL8BZg', 'review_count': 110, 'city': 'Haddon Heights'}
# {'business_id': '9qR3g_ABCk5kZCYFx82AlQ', 'review_count': 166, 'city': 'Lansdale '}
# {'business_id': 'bUCKMsxYP3dlzm5JqzozSQ', 'review_count': 79, 'city': 'Souderton'}
# {'business_id': '6TaGkietsy7XvFiSf5f7MA', 'review_count': 45, 'city': 'Merchantville'}
# {'business_id': 'VdJ2Ln27tfM258MaT_qIXw', 'review_count': 34, 'city': 'Aldan'}
# {'business_id': '8pqdJjefYq-a9IBSJJmKwA', 'review_count': 2577, 'city': 'Philadelphia'}
# {'business_id': 'vpBj-Dq51WFqsbnIiUWEww', 'review_count': 20, 'city': 'Cheltenham'}
# {'business_id': 'PusWGOxiMhfn64oSBV-i1Q', 'review_count': 7, 'city': 'Earlington'}
# {'business_id': 'TMr0nPTPa0oeLpy0gu2HZQ', 'review_count': 19, 'city': 'Folcroft'}
# {'business_id': 'xP5o6PVU3tWOixLJTIdVVA', 'review_count': 377, 'city': 'Alton'}
# {'business_id': '--8IbOsAAxjKRoYsBFL-PA', 'review_count': 27, 'city': 'Gentilly'}
# {'business_id': 'AFeVNAyxenAr5x-56ulL6A', 'review_count': 311, 'city': 'Meridian'}
# {'business_id': 'XDMno4l95AXgYOd0yDtHZA', 'review_count': 125, 'city': 'Kenner'}
# {'business_id': '0EbYHXAKFo9IsFhmZHD1Nw', 'review_count': 78, 'city': "O'fallon"}
# {'business_id': '0f69gYJBDkWpi-F9JlPSkA', 'review_count': 160, 'city': 'Hendersonville'}
# {'business_id': 'mUrZm3si8_P3uQyCiOPe9w', 'review_count': 40, 'city': 'Limerick'}
# {'business_id': 'VHA-b1NH4tIZB_IVEf_pmA', 'review_count': 452, 'city': 'East Norriton'}
# {'business_id': 'cQDUoid9D_hF8L2GxtHWOw', 'review_count': 8, 'city': 'Scott Air Force Base'}
# {'business_id': 'HWLXfIxmhG3hETxlhXEg7g', 'review_count': 119, 'city': 'Turnersville'}
# {'business_id': 'z0cvWq9SVVIvCUEF28utdQ', 'review_count': 10, 'city': 'Croydon'}
# {'business_id': 'TyG_RravUK9gbpj3G5PNyQ', 'review_count': 35, 'city': 'Glendora'}
# {'business_id': '7C2iDdFiXcHB5SyaGn_tWw', 'review_count': 120, 'city': 'Collingswood'}
# {'business_id': 'XmSPtkPq9zNKSNcv_F7XYw', 'review_count': 29, 'city': 'Brooklawn'}
# {'business_id': 'ZMQsdYyB5NCBhwSrtBXiHg', 'review_count': 153, 'city': 'Greenwood'}
# {'business_id': '9MMy2Ze9IDlb6fKGwZIlNQ', 'review_count': 6, 'city': 'Penns Grove'}
# {'business_id': '7sOqa_LFDHEtiFzNFZBw4A', 'review_count': 7, 'city': 'Port Hueneme'}
# {'business_id': 'Uv1x00qbS5h3R4J6leqQbQ', 'review_count': 10, 'city': 'Phila'}
# {'business_id': 'Izj9SZocemNgqLKi4h8R4w', 'review_count': 514, 'city': 'Dunedin'}
# {'business_id': 'BsnP3lXh-QaOSgAw2t-omA', 'review_count': 152, 'city': 'Manayunk'}
# {'business_id': 'hN4n_a3FTedoJP1h8ZbjTg', 'review_count': 7, 'city': 'Secane'}
# {'business_id': 'hpUzCbmpC42NFuGvxToVOA', 'review_count': 23, 'city': 'Sellersville'}
# {'business_id': 'EKnEztWS7SUraJEq8zZDJg', 'review_count': 86, 'city': 'Hatfield'}
# {'business_id': 'Zo2tRIvtAfoENtbw2USoYg', 'review_count': 13, 'city': 'Houston'}
# {'business_id': 'U-RlkCheEvJxDn9BCyiDWg', 'review_count': 15, 'city': 'Mont Clare'}
# {'business_id': '0B0L4P5YGgbNeb7Koyez9A', 'review_count': 6, 'city': 'Bethalto'}
# {'business_id': 'dVydE-KsDbe6aIEA1REtWg', 'review_count': 37, 'city': 'Deptford Township'}
# {'business_id': 'wtnxz8f51VY81Ng8rr_8Dg', 'review_count': 106, 'city': 'Avon'}
# {'business_id': 'gHMUdZqJFLTGO7Lw-3h35A', 'review_count': 7, 'city': 'PHILADELPHIA'}
# {'business_id': '1pp0D12fv1aObregTlkArg', 'review_count': 165, 'city': 'Voorhees Township'}
# {'business_id': 'SVp-oQzF2x07Yv38ZKbaHA', 'review_count': 71, 'city': 'Troy'}
# {'business_id': 'sh8T2qHvj5LGyeW4S8baJg', 'review_count': 64, 'city': 'Gallatin'}
# {'business_id': 'Lqp0nD8Mxdkp7MYh_hpI0g', 'review_count': 11, 'city': "Land o' Lakes,"}
# {'business_id': 'NweYGXELGcYZ0I_eRWJiCQ', 'review_count': 59, 'city': 'Tabernacle'}
# {'business_id': '6Ty-KKWq6hLZYW8DWEHYvg', 'review_count': 2396, 'city': 'New Orleans'}
# {'business_id': 'PDTart2-ChFYdNjECtreQg', 'review_count': 291, 'city': 'Mt Juliet'}
# {'business_id': 'JxxbfK1Y_gBWd_3enL5s5g', 'review_count': 5, 'city': 'Gloucester City'}
# {'business_id': 'vSRdQJkcExJqR5l3QPmy5w', 'review_count': 155, 'city': 'Newtown'}
# {'business_id': 'cUhcvbcl6UQ96JTSvMKTVA', 'review_count': 8, 'city': 'Logan Township'}
# {'business_id': '9ud6Cea04gzJ1ktpT4sVNw', 'review_count': 62, 'city': 'Palmyra'}
# {'business_id': '8bXN8rouWRTKxvfuHNDRBw', 'review_count': 274, 'city': 'Philadephia'}
# {'business_id': 'hHe33LafwSlyc6Z_jxyBLA', 'review_count': 23, 'city': 'Richboro'}
# {'business_id': 'ah3B5TN3cYUF4v7te-qlPQ', 'review_count': 11, 'city': 'Swansea'}
# {'business_id': 'g0fYqQRRKmYIfChE4jMLsg', 'review_count': 10, 'city': 'Bennington'}
# {'business_id': '8oHKJvWMqOx_PrSIG4odAw', 'review_count': 30, 'city': 'St Albert'}
# {'business_id': '7RaoxmyA1C2pXfce9Kz-DA', 'review_count': 144, 'city': 'Delran'}
# {'business_id': 'qKNIyugDH3SOnxv1QbibFg', 'review_count': 88, 'city': 'Shiloh'}
# {'business_id': 'DnJknR_kcMPxc17D2hNJmw', 'review_count': 29, 'city': 'Ewing'}
# {'business_id': 'je2aXwUvTrZBOGSh4Wd_ww', 'review_count': 23, 'city': 'La Vergne'}
# {'business_id': '05wBSwtKBCad4B9GpzXY_g', 'review_count': 443, 'city': 'Madison'}
# {'business_id': '54HLqEsg7GM0DCJm6dNSCg', 'review_count': 23, 'city': 'Skippack Village'}
# {'business_id': 'fFPSKs3nCpj5EcOWPc7ltg', 'review_count': 98, 'city': 'Castleton'}
# {'business_id': 'M7o1fV1dFPWx-gWJ7s5jwg', 'review_count': 56, 'city': 'Land O Lakes'}
# {'business_id': '5gIfmupQTP3Lk4wIgNfoEQ', 'review_count': 325, 'city': 'Fishers'}
# {'business_id': '5vObJIHLO-QOMrw_MvC4rA', 'review_count': 849, 'city': 'Carpinteria'}
# {'business_id': 'KhNV9XW9024TDJOQCe2-2A', 'review_count': 26, 'city': 'Tampa - South'}
# {'business_id': 'wbwDE3g8j4w-TGy_E6dMSw', 'review_count': 266, 'city': 'Temple Terrace'}
# {'business_id': 'oriZ5IOonGHHRkmeSHNwiw', 'review_count': 115, 'city': 'Brownsburg'}
# {'business_id': 'Nhci37qY0HPCNWc5UQul9w', 'review_count': 266, 'city': 'Gretna'}
# {'business_id': '0ltwnq7Q2S76Fu-0W0HNPg', 'review_count': 88, 'city': 'Medford'}
# {'business_id': 'Xck6n6jSGrQu_jl15T4SzQ', 'review_count': 18, 'city': 'Mooresville'}
# {'business_id': 'v_G3vuI6_CuBg7jjTSCaAQ', 'review_count': 40, 'city': 'Feasterville-Trevose'}
# {'business_id': '0zipcAy98kEyawFxZFSfdg', 'review_count': 11, 'city': 'Kenneth City'}
# {'business_id': 'n8XegxgMI6UWjEjTB8FoGw', 'review_count': 15, 'city': 'Tennesse'}
# {'business_id': 'pqmpsRtNxntXcCfkExPvmA', 'review_count': 200, 'city': 'Spring City'}
# {'business_id': 'Np1ai5foERVFpeJ8tu-alg', 'review_count': 8, 'city': 'Danville'}
# {'business_id': 'TB_ZrT48wouXF4W-pi0N1w', 'review_count': 12, 'city': 'land o lakes'}
# {'business_id': 'AuKcDOfJGvQUO7xlSn8n_Q', 'review_count': 11, 'city': 'Pagedale'}
# {'business_id': 'Q_J9QnC34E-Q50oR1kwfkg', 'review_count': 87, 'city': 'Pennsauken Township'}
# {'business_id': '_OMGZ3TXOfN2By7skat_bw', 'review_count': 795, 'city': 'Saint Louis'}
# {'business_id': 'YpEhr0oOEw8i_-s_Y_d83A', 'review_count': 7, 'city': 'Lavergne'}
# {'business_id': 'EEs_jK26kMA87hc-5_Ni8Q', 'review_count': 36, 'city': 'Richmond Heights'}
# {'business_id': 'NnXtMdEJ4QRgaw7hTgbkgg', 'review_count': 379, 'city': 'Lansdale'}
# {'business_id': 'pQ_bN3YhTrswGAfRWfH-gA', 'review_count': 5, 'city': 'Frederick'}
# {'business_id': 'VENBnW8AF4jYTBbekO8X2A', 'review_count': 14, 'city': 'Hilltown'}
# {'business_id': 'pzO28TQMIhlGxMi-08XcsA', 'review_count': 5, 'city': 'Zephryhills'}
# {'business_id': 'KRpi9ZJHt65jY4DfwI7VrA', 'review_count': 216, 'city': 'Maplewood'}
# {'business_id': '0PkCShlrhrJTajj6XsMOVQ', 'review_count': 12, 'city': 'Saint Albert'}
# {'business_id': 'J2LA_8y8FtiVNT3PM8fstQ', 'review_count': 21, 'city': 'boise'}
# {'business_id': 'Rb7yIraC6aMQ5gG3UbU-dA', 'review_count': 164, 'city': 'Oaks'}
# {'business_id': 'AOdw-xjhc-ZRVhJzAgJxSw', 'review_count': 84, 'city': 'Rockledge'}
# {'business_id': 'EF_9W5s9lFSjv4forNxwng', 'review_count': 328, 'city': 'Olivette'}
# {'business_id': 'uDBF4DADIAi14NXUdU9L5w', 'review_count': 9, 'city': 'Picture Rocks'}
# {'business_id': 'g-vBH_blPylAXzR-P0DtOA', 'review_count': 119, 'city': 'Maple Shade Township'}
# {'business_id': 'IvMEGUlmbDZVzftmRCLdDg', 'review_count': 190, 'city': 'Wayne'}
# {'business_id': 'AyTluPk6mX943sH0f7EC8g', 'review_count': 76, 'city': 'Westampton'}
# {'business_id': 'd6UK0YdoQe9bjmEc4_enNg', 'review_count': 11, 'city': 'Boise City'}
# {'business_id': 'AVCjn9uVgkjIRM3uYrEf1w', 'review_count': 23, 'city': 'Sullivan'}
# {'business_id': 'TEZa6FxKK1JfWmHWp1hR2w', 'review_count': 30, 'city': 'Hamilton'}
# {'business_id': '_QuTMcMk2_2UM3gDOnuwyQ', 'review_count': 95, 'city': 'Medford Lakes'}
# {'business_id': 'Me4mO0eMVp5ZY3Smznr7tQ', 'review_count': 25, 'city': 'Claymont'}
# {'business_id': 'YBq6blbEs3Vc43x-G0mC8w', 'review_count': 154, 'city': 'Blue Bell'}
# {'business_id': '2MENWD-g4QVbeMVGdCGC6A', 'review_count': 248, 'city': 'St Charles'}
# {'business_id': 'rFQn-ANlTA8CQd8PtF-wdw', 'review_count': 18, 'city': 'Magnolia'}
# {'business_id': 'qc7AgRToxyrZwx434dSdqg', 'review_count': 267, 'city': 'Clearwater Beach'}
# {'business_id': '5xIcqp5q-6mw1FKaKpRCxw', 'review_count': 141, 'city': 'Pike Creek'}
# {'business_id': '_Qquii4aOFUqA5QRlSdk9w', 'review_count': 13, 'city': 'Eddystone'}
# {'business_id': 'pnxL0sjTp4EjL93PvdQe-w', 'review_count': 19, 'city': 'Jeffersonville'}
# {'business_id': '6JDhEP9MkUCLBRzn_F2Xkw', 'review_count': 45, 'city': 'Strafford'}
# {'business_id': 'XZPL988dC2lRVAfFcuH7Xw', 'review_count': 16, 'city': "Town 'n' Country"}
# {'business_id': 'UMkxsBxze3nDpi3ogakw2Q', 'review_count': 10, 'city': 'Westmont - Haddon Towsship'}
# {'business_id': 'IqitQsWPnTVTCJIRqh80lA', 'review_count': 206, 'city': 'Plainfield'}
# {'business_id': 'J6yMHNxEX16DiWKz0kQScw', 'review_count': 24, 'city': 'Swarthmore'}
# {'business_id': 'Bcr1rVZLWN_6azP0KL1Qug', 'review_count': 135, 'city': 'Havertown'}
# {'business_id': '1ySb0EDc_DEiFwcyYbIdXA', 'review_count': 32, 'city': 'Beech Grove'}
# {'business_id': 'FVcIeaJY8vTnt9AksAVFaw', 'review_count': 5, 'city': 'Woolwich Township'}
# {'business_id': 'kl_lEsUp7Q41E_X4ajgbgw', 'review_count': 12, 'city': 'Earth City'}
# {'business_id': 'SOxpJAqr3gBlir0jUkQVhw', 'review_count': 12, 'city': 'Caseyville'}
# {'business_id': 'rUlrzgX_hVZo7xtzbdKwRw', 'review_count': 13, 'city': 'Washington Crossing'}
# {'business_id': 'bdth7r1brx9yRU7sYwF9jQ', 'review_count': 266, 'city': 'Ballwin'}
# {'business_id': 'iCZga7FcYiOjYiTrhcAAXw', 'review_count': 5, 'city': 'Belleair Bluffs'}
# {'business_id': 'DVQjaS72kFLo1nmOjeQ4Tg', 'review_count': 112, 'city': 'Fenton'}
# {'business_id': 'Ck1NzGMoJIADtCVSp6sb1A', 'review_count': 15, 'city': 'Redington Shores'}
# {'business_id': 'RqwoIHg6kUlWXGEh2N428A', 'review_count': 7, 'city': 'New Whiteland'}
# {'business_id': 'gu1XBRHx0v4PvFKcEYX65Q', 'review_count': 48, 'city': 'Crestwood'}
# {'business_id': 'e0DU7_0mfalr-lnyUafiag', 'review_count': 154, 'city': 'Montecito'}
# {'business_id': '7ryp_trAuUeh6UuUP2AkQg', 'review_count': 12, 'city': 'Plumsteadville'}
# {'business_id': '0d1dpaZqcm7litFOJl7atA', 'review_count': 1315, 'city': 'St. Petersburg'}
# {'business_id': 'wkIc7MTnnGkqZC5aJyKimA', 'review_count': 287, 'city': 'King Of Prussia'}
# {'business_id': 'j632484XwUf_fcYr2lFuXA', 'review_count': 7, 'city': 'St. Rose'}
# {'business_id': '5CTHq4_zCjPi56h3c7Fmtg', 'review_count': 134, 'city': 'Arnold'}
# {'business_id': 'y-IibTHCmsImPpJhfJNNIg', 'review_count': 5, 'city': 'Redingtn Shor'}
# {'business_id': 'zlIY4ErEUTijH14jU9sk1g', 'review_count': 37, 'city': 'Lower Gwynedd'}
# {'business_id': 'PzZFqJmAMuXWiTgCV1zt4g', 'review_count': 63, 'city': 'Paoli'}
# {'business_id': 'tBO9ttcLUjsQzpCApeWu-g', 'review_count': 189, 'city': 'Norristown'}
# {'business_id': '0XBEKrwSPOQaMTBpd_v2hA', 'review_count': 34, 'city': 'Wynnewood'}
# {'business_id': 'wtaBPP6fCHU4nvar9fKeuQ', 'review_count': 26, 'city': 'Barrington'}
# {'business_id': 'WP3W43z9Dryyunf8J8YhFQ', 'review_count': 35, 'city': 'High Ridge'}
# {'business_id': 'yuNf6vYaIZYe88g6pouAiA', 'review_count': 108, 'city': 'Narberth'}
# {'business_id': 'nms5AGFDKTMWq_bqDZEIJA', 'review_count': 39, 'city': 'Apollo Beach'}
# {'business_id': 'eIhEI_vIxj88ldlkw0W_7w', 'review_count': 68, 'city': 'Folsom'}
# {'business_id': 'ONmS8r1C0F0vglz2nKjkPA', 'review_count': 30, 'city': 'Belle Chasse'}
# {'business_id': 's-MNI1PryGuQGQx4fZiFag', 'review_count': 5, 'city': 'Waggaman'}
# {'business_id': '06s46kJWbjIomKy_j-slew', 'review_count': 21, 'city': 'Sumneytown'}
# {'business_id': 'PLnyG-qXpknNv1RUIvUSWA', 'review_count': 29, 'city': 'Elsmere'}
# {'business_id': 'FMUvCniLe8m8BHSYUsnH2w', 'review_count': 177, 'city': 'Largo'}
# {'business_id': 'NOhexpjqPK3RP6DBDl17AA', 'review_count': 12, 'city': 'Wyndmoor'}
# {'business_id': 'i_ebZdLk-SePyN6VQYdL-g', 'review_count': 266, 'city': 'Malvern'}
# {'business_id': 'OZcl2HOUXAHuICrh5d2WjQ', 'review_count': 856, 'city': 'Clayton'}
# {'business_id': 'SL2KmQz1NFdVhXWhJT6wJQ', 'review_count': 9, 'city': 'Upland'}
# {'business_id': 'A_AEG20YPuVW7Ao7gkHicg', 'review_count': 598, 'city': 'Boise'}
# {'business_id': 'g1p9zAp_OKuVdAivkYr5JQ', 'review_count': 22, 'city': 'Lawrence Township'}
# {'business_id': 'aw5GN4yk6r0r9e_5TdiLFQ', 'review_count': 64, 'city': 'Chester Springs'}
# {'business_id': 'cV5bt3MYriACL8-EHOuQag', 'review_count': 59, 'city': 'Devon'}
# {'business_id': 'RVzroffkQf6P8uv4qCBh8w', 'review_count': 265, 'city': 'Exton'}
# {'business_id': 'N0a-Hfq1jg6yATQt3j04vw', 'review_count': 53, 'city': 'Jefferson'}
# {'business_id': 'ATJX6w8d1W_h9y9VuRG7DA', 'review_count': 7, 'city': 'Montgomery Township'}
# {'business_id': 'NDKuZUtq2-JUDc6Tu1kScA', 'review_count': 10, 'city': 'Bordentown Township'}
# {'business_id': 'EfYxcjn8pOheZUcP47JiBw', 'review_count': 31, 'city': 'Oreland'}
# {'business_id': '4fLMC6B2USFFRaPSfJSKlA', 'review_count': 59, 'city': 'Evesham Township'}
# {'business_id': 'mC-Yr2jvuTz47l1hDhXAXw', 'review_count': 16, 'city': 'Berlin'}
# {'business_id': 'uSBO3RM6JTbckZ63PEIW2w', 'review_count': 22, 'city': 'Pleasant View'}
# {'business_id': 'yRm3Xt90drxSKXegohsPGQ', 'review_count': 170, 'city': 'Ruskin'}
# {'business_id': 'Ynbd79O142LHhFWZAce1TA', 'review_count': 294, 'city': 'Safety Harbor'}
# {'business_id': 'zkzXnf9zRNHX5Gy2wFK9MA', 'review_count': 6, 'city': 'Erial'}
# {'business_id': '4_VfMHPjM2VgqQdwGQL7rw', 'review_count': 58, 'city': 'Trinity'}
# {'business_id': 'rM_UR_odsWa-LyXMPczfdw', 'review_count': 75, 'city': 'Hainesport'}
# {'business_id': 'iBtZh4BOCjW-ZH3rrbSWVA', 'review_count': 76, 'city': 'Morton'}
# {'business_id': 'juAJa5f518T7BZu5_42Kng', 'review_count': 104, 'city': 'Town and Country '}
# {'business_id': '_ju1BXAF5g5QtAFfZZKO1g', 'review_count': 83, 'city': 'Greenville'}
# {'business_id': 'tfkE9AOK5zmiJ9nX0jo5tg', 'review_count': 174, 'city': 'Trevose'}
# {'business_id': 'z94Wvk0OOK93p1ZoUjuszQ', 'review_count': 28, 'city': 'Thorndale'}
# {'business_id': '549RHbvwLZ6l7ht5Le7Sug', 'review_count': 240, 'city': 'Doylestown'}
# {'business_id': 'WtC6tR6Wq9g_vguMalpliQ', 'review_count': 61, 'city': 'Schwenksville'}
# {'business_id': 'Ei0wJeADbNtwvA9CrvknJw', 'review_count': 37, 'city': 'Primos'}
# {'business_id': 'GXXbsAsNLGuLYTQKHb0XMw', 'review_count': 280, 'city': 'Royersford'}
# {'business_id': '0kRJxKwyVeHbnUIDPd6_kA', 'review_count': 18, 'city': 'Bryn Athyn'}
# {'business_id': '8r23xbXXpI-g8MJYd4jT2A', 'review_count': 89, 'city': 'Villanova'}
# {'business_id': 'SqR-SVD8otqLguw0rFUVvA', 'review_count': 101, 'city': 'Westville'}
# {'business_id': 'AESQSIG26hePM6RbKH0J2Q', 'review_count': 8, 'city': 'Staint Albert'}
# {'business_id': 'NCKTDyUdN2UkVEPKWIwdSA', 'review_count': 214, 'city': 'West Chester'}
# {'business_id': '1PB7PMzl3SSVjaoRuJ2mJg', 'review_count': 6, 'city': 'Pittsgrove'}
# {'business_id': 'S2tSSs1ra0DxInz4HXa99g', 'review_count': 25, 'city': 'Glen Carbon'}
# {'business_id': 'VSBDNSp-rGItt1Sl70jnew', 'review_count': 91, 'city': 'Glenside'}
# {'business_id': 'UE1j-OSkOi5H_VoBJkvJfg', 'review_count': 6, 'city': 'Meraux'}
# {'business_id': '3TpSuWBTfoHyALIePVpNXw', 'review_count': 88, 'city': 'Treasure Island'}
# {'business_id': '1HRAmY7rTMKaY9-rNrppzg', 'review_count': 191, 'city': 'Kirkwood'}
# {'business_id': 'OAHRMd971k-yDQwRxzgc2g', 'review_count': 357, 'city': 'Tampa Bay'}
# {'business_id': '9nh4bTVAD9rII2hLic-uCA', 'review_count': 17, 'city': 'Kuna'}
# {'business_id': 'BNNqq4Ut7tmnVAYiaEhMsw', 'review_count': 129, 'city': 'Lafayette Hill'}
# {'business_id': 'FAmVbvlu58BbpVuJlAUuVw', 'review_count': 154, 'city': 'Old Hickory'}
# {'business_id': 'Wjof0zPFYr1MlgvenXohFw', 'review_count': 180, 'city': 'Catalina'}
# {'business_id': 'HkdIGOvJunTJG8hR1l09Cw', 'review_count': 22, 'city': 'North Redington Beach'}
# {'business_id': '1myhYEZ2EC98hrNMw7KAqg', 'review_count': 187, 'city': 'Fort Washington'}
# {'business_id': 'uxoQdZD3mEptaPohiLQg1w', 'review_count': 62, 'city': 'Kimberton'}
# {'business_id': '4mYPqTpCjHqx8Ee4TIERXA', 'review_count': 9, 'city': 'Green Lane'}
# {'business_id': 'HbZDCqcp3wWEJ21M9sfTXw', 'review_count': 151, 'city': 'Port Richey'}
# {'business_id': 'AtIGlkUITdQFhAG_JWp-Og', 'review_count': 140, 'city': 'Hermitage'}
# {'business_id': 'MeJ4afqMv8_JjTHgjdrg_Q', 'review_count': 163, 'city': 'North Wales'}
# {'business_id': 'vJLbVnnZFb_kiUMjGIWsSg', 'review_count': 8, 'city': 'Stanton'}
# {'business_id': '_8GPLch3GAnhOmymvG947w', 'review_count': 28, 'city': 'Clermont'}
# {'business_id': '8kbz7-YZpbeyyewV69ySsA', 'review_count': 17, 'city': 'Milmont Park'}
# {'business_id': 'LvKmlaBbed8RD6Suh0ZngA', 'review_count': 5, 'city': 'Marshallton'}
# {'business_id': 'Rym1VW90lJR-c-x7N8Q64A', 'review_count': 133, 'city': 'Pilesgrove'}
# {'business_id': 'GchRJYK1DDvyv45AMkvlMg', 'review_count': 16, 'city': 'Monroe Township'}
# {'business_id': 'nwN92Uje-xIKE5voPTTvBQ', 'review_count': 609, 'city': 'Belleville'}
# {'business_id': '4_r9IYC0BY2-E9Wemtv2sA', 'review_count': 84, 'city': 'Bryn Mawr'}
# {'business_id': '3qgz5OPfl7CRa3igH4s1Sg', 'review_count': 338, 'city': 'East Nashville'}
# {'business_id': 'xV7rWdtEHTy3DySAAux0aQ', 'review_count': 15, 'city': 'San Antonio'}
# {'business_id': 'Ctg4LV9zEuXskGETDUewlQ', 'review_count': 32, 'city': 'Claerwater'}
# {'business_id': '3vIIV9SNBbP9TxB9iHXlPg', 'review_count': 10, 'city': 'Jennings'}
# {'business_id': 'Zz8Fq463yHTAg9KXBrMb3g', 'review_count': 8, 'city': 'Cumberland'}
# {'business_id': 'IlVFBKxhiLstwEqDq3TP6Q', 'review_count': 88, 'city': 'Affton'}
# {'business_id': 'dtF124e6IaTIzyT0Gvp1Uw', 'review_count': 81, 'city': 'Haddonfield'}
# {'business_id': '1R7BF5Kbwcc9Yg_qG5-Tbg', 'review_count': 5, 'city': 'Holicong'}
# {'business_id': 'mZQT4u4rTzS7ZPC-41yiVw', 'review_count': 7, 'city': 'Evesham'}
# {'business_id': 'TCBr4-oSF8AOYmvl-_b-Jw', 'review_count': 62, 'city': 'Roxborough'}
# {'business_id': 'j8YIaLJ5TnVjtPApaZeyjA', 'review_count': 166, 'city': 'Saint Charles'}
# {'business_id': '7Qkj7_DBptnXGHAG8Qg4cw', 'review_count': 156, 'city': 'Gulfport'}
# {'business_id': 'Of3xjnH-jwwfZule44ihOg', 'review_count': 299, 'city': 'Conshohocken'}
# {'business_id': '3h2ptMAJfBI7MFW4z7smog', 'review_count': 55, 'city': 'Vail'}
# {'business_id': '-bbQKRo6kP8p_FKjm4xu0g', 'review_count': 17, 'city': 'Treasure Is'}
# {'business_id': 'gERx_PW1-hjWR_UCsTMH1g', 'review_count': 102, 'city': 'Essington'}
# {'business_id': 'tZy556-b1uO9pcy0WsumIA', 'review_count': 78, 'city': 'Violet'}
# {'business_id': 'ckAA5u2D8bGqQZ0JFjLH4Q', 'review_count': 109, 'city': 'W Cherry Hill'}
# {'business_id': 'CCjzAzmJzvBm-dvfhSAScg', 'review_count': 5, 'city': 'Eddington'}
# {'business_id': 'OeVPCsHpZbgJ7Cjd4fVtzg', 'review_count': 158, 'city': 'Nolensville'}
# {'business_id': 'bkBHOBQ-R6CVTMiVGiJQOg', 'review_count': 9, 'city': 'Berkeley'}
# {'business_id': 'kZu9sbMkvbpDCpqmm6TpOQ', 'review_count': 16, 'city': 'Telford'}
# {'business_id': '-xeTwslZeVQ5MhcXIVIMSQ', 'review_count': 81, 'city': 'Lindenwold'}
# {'business_id': 'jEncyrIzDVWn9wgsfhh8yA', 'review_count': 6, 'city': 'SAINT PETERSBURG'}
# {'business_id': 'nAbese1E1H5TwZntoEyfzg', 'review_count': 586, 'city': 'Brentwood'}
# {'business_id': 'Bl6QNjzmtG779fI5Hm4gfA', 'review_count': 249, 'city': 'Warminster'}
# {'business_id': 'EMti-iNn83SGp3z6LngDWQ', 'review_count': 77, 'city': 'St.Ann'}
# {'business_id': '1TAHFIs5ETVVB9X9R3Jwrw', 'review_count': 5, 'city': 'Mccordsville'}
# {'business_id': '5dRjsAcaY1XA1i7pH99B_A', 'review_count': 92, 'city': 'St.Louis'}
# {'business_id': 'xph-XbBCctanFTLxWHGoPg', 'review_count': 6, 'city': 'Woodlyn'}
# {'business_id': 'timvnbWarN7ng8qzhyTyYA', 'review_count': 5, 'city': 'Saint Petersburg Beach'}
# {'business_id': 'khnNWa_my3oQQghGPuILhg', 'review_count': 358, 'city': 'Carmel'}
# {'business_id': '7-v_jV-eIX3lwh60ePElag', 'review_count': 19, 'city': 'Green Park'}
# {'business_id': 'TXRBp01bIr60dSGYsu8oxQ', 'review_count': 87, 'city': 'Huntingdon Valley'}
# {'business_id': '-3LGekWQ5iHMQO1a9_DDbw', 'review_count': 28, 'city': 'Lawrenceville'}
# {'business_id': 'eevZhYOfKqMWJIUfFWgZfg', 'review_count': 88, 'city': 'Feasterville Trevose'}
# {'business_id': 'hGvXETyQUGkjfyhHmM3q_w', 'review_count': 11, 'city': 'Virginia City'}
# {'business_id': 'kvle5j_7tlzX5-vRXjWUGw', 'review_count': 30, 'city': 'East Alton'}
# {'business_id': 'Vfhz9Xwi_Fi34PYXUK9Qyg', 'review_count': 10, 'city': 'Safety Harbor,'}
# {'business_id': 'FAXl9Xchw8li_2las5Ufxg', 'review_count': 7, 'city': 'Zieglersville'}
# {'business_id': 'gkOSWr5ae8sC-FVHnpGGCg', 'review_count': 19, 'city': 'Norwood'}
# {'business_id': 'OiNrqVY54pHo5bsxH9zmCg', 'review_count': 26, 'city': 'Hazelwood'}
# {'business_id': '5ewePyN_mEE_79OmYyYBEA', 'review_count': 90, 'city': 'Sahuarita'}
# {'business_id': 'lKh3mvAqL8KMTHgcnvkaFg', 'review_count': 80, 'city': 'Swedesboro'}
# {'business_id': 'fjtjcBJyMomt8iNulJZHPw', 'review_count': 5, 'city': 'Pass-a-Grille'}
# {'business_id': 'bYv6m-j8O8CySqEE4Wh_jQ', 'review_count': 95, 'city': 'Clementon'}
# {'business_id': 'YOiNEC9ERJ9nVBFnhvMilA', 'review_count': 11, 'city': 'Mantua'}
# {'business_id': 'xafbpaLav1JniOyoLlhHrA', 'review_count': 129, 'city': 'Imperial'}
# {'business_id': 'oWk7BiqZG99slmVSq6fmWQ', 'review_count': 104, 'city': 'Ambler'}
# {'business_id': '_vLfidpLDYHfZ_KnFZ75Lg', 'review_count': 215, 'city': 'Isla Vista'}
# {'business_id': 'NO_U5ZaGINbGYnk3aDTKDA', 'review_count': 43, 'city': 'Moorestown'}
# {'business_id': 'csfq_i-3HcyBFt50JK344g', 'review_count': 11, 'city': 'Saintt Petersburg'}
# {'business_id': 'eED2QZ4cf-0oB_91jfG9rA', 'review_count': 30, 'city': 'Trooper'}
# {'business_id': '7Fk8yx8fTT3wCb6Nf2-a7Q', 'review_count': 10, 'city': 'New Britain'}
# {'business_id': 'hVHjRiHA0nVLbRqUkBI7xg', 'review_count': 9, 'city': 'Eastampton'}
# {'business_id': 'cWhEVY0KMmIRTVR-sjNusQ', 'review_count': 91, 'city': 'Upper Darby'}
# {'business_id': 'dRNrAjTbe9DCdpJUIW4c0g', 'review_count': 30, 'city': 'Zieglerville'}
# {'business_id': '540XY9UXBi2T2x8K8hq1HA', 'review_count': 49, 'city': 'Haddon Twp'}
# {'business_id': 'PzTnZPaDVLMXkFl6EQfULw', 'review_count': 71, 'city': 'Runnemede'}
# {'business_id': '8-6ksWmeZdjBLcvKQKYgRA', 'review_count': 47, 'city': 'West Berlin'}
# {'business_id': 'UX-OIPvEx8ATtVMGjSEcvQ', 'review_count': 57, 'city': 'Sewell'}
# {'business_id': 'bp5Mk2d0qofUeF5uLauIbg', 'review_count': 1391, 'city': 'Metairie'}
# {'business_id': 'yKgxtgSBkDeuBsfjQVV-jA', 'review_count': 5, 'city': 'Smithton'}
# {'business_id': 'E5oa5ubbMvA1Ooypvis7jA', 'review_count': 134, 'city': 'Willow Grove'}
# {'business_id': 'fHA0LeWde2s9y3gdsvCvCw', 'review_count': 23, 'city': 'Audubon'}
# {'business_id': 'dVIdm7oKOlTs_1nh8w3yOA', 'review_count': 6, 'city': 'Norriton'}
# {'business_id': 'BS3Oi49x4vEPep1IFFiYSg', 'review_count': 172, 'city': 'White House'}
# {'business_id': '5oZAv6_X_1jCoHZ1ozc_QA', 'review_count': 103, 'city': 'Williamstown'}
# {'business_id': 'XtuWejrrZMZGkRMxxesKJw', 'review_count': 237, 'city': 'New Port Richey'}
# {'business_id': 'ij01QEUh2uK3W27dN4knwQ', 'review_count': 16, 'city': 'Godfrey'}
# {'business_id': 'oES5_X2z1tDEzH20x_igtQ', 'review_count': 97, 'city': 'Gibsonton'}
# {'business_id': '53cWQoa_wCOTQtcqp-FkjA', 'review_count': 26, 'city': 'Hamilton Township'}
# {'business_id': 'v7-C0L3Ua1maetDO8nI4Yw', 'review_count': 10, 'city': 'Haverford'}
# {'business_id': 'b2kjgx_Py8_mC8xXkTnRIg', 'review_count': 7, 'city': 'Stead'}
# {'business_id': 'w2NiG6ftSvpU81eRghLIjQ', 'review_count': 132, 'city': 'Creve Coeur'}
# {'business_id': 'pmddHTytEL_RzVQSo3X5aQ', 'review_count': 19, 'city': 'Malaga'}
# {'business_id': 'Wf9Ir1pvAmQL5GXgBEvCcA', 'review_count': 502, 'city': 'Tierra Verde'}
# {'business_id': 'Ty3w8cNBGXLMMpx_t9KUAg', 'review_count': 32, 'city': 'Boyertown'}
# {'business_id': 'yoofLOoaTgzMwfkr-f15Iw', 'review_count': 65, 'city': 'Morrisville'}
# {'business_id': 'eeADf33x3JcyvmZCPYBSSQ', 'review_count': 30, 'city': 'Lebanon'}
# {'business_id': 'zgfKSWwxcBgBir_mlq0CIg', 'review_count': 333, 'city': 'New Hope'}
# {'business_id': 'GhGoWiF1dP3tnP_WSPdi2g', 'review_count': 11, 'city': 'Shrewsbury'}
# {'business_id': 'yhEbjRzlfCLanl_-LUreVA', 'review_count': 138, 'city': 'Horsham'}
# {'business_id': 'B2Tuf5M1wQhdwAKnD-w7Yw', 'review_count': 286, 'city': 'Marrero'}
# {'business_id': '0mLgF2T8wVDj7NFtoRtpQQ', 'review_count': 316, 'city': 'St. Pete Beach'}
# {'business_id': '4RLS-xn9hHxm8-HTLXf8Og', 'review_count': 100, 'city': 'Verdi'}
# {'business_id': 'bcmgbIMjlPJWkyv0k1XJzA', 'review_count': 119, 'city': 'Levittown'}
# {'business_id': 'oKPOwM0RQXCfNdM_s8TFhw', 'review_count': 152, 'city': 'Bordentown'}
# {'business_id': 'O9I8HKV45a9PbjujKSa_YA', 'review_count': 167, 'city': 'Hernando Beach'}
# {'business_id': 'W7S5xV7aOIWjcq0Xd4KKLg', 'review_count': 61, 'city': 'Jenkintown'}
# {'business_id': '7-fSs7RaOD-EEIflooWRsg', 'review_count': 14, 'city': 'Maryville'}
# {'business_id': '7McQCpcpjyAA_TaQPlsirg', 'review_count': 378, 'city': 'Mount Laurel'}
# {'business_id': 'o1DuWXCV_kg_mSqNOxUdew', 'review_count': 801, 'city': 'Reno'}
# {'business_id': '2KlvBObysXe00p7phB45_A', 'review_count': 43, 'city': 'Terrytown'}
# {'business_id': 'l6IoWDxAufetWhxPF04Q_g', 'review_count': 77, 'city': 'Columbus'}
# {'business_id': 'WZm72JqVRfpw2Pu3vag9gw', 'review_count': 335, 'city': 'Oldsmar'}
# {'business_id': 'CADaY34LnEGjpSpU7Lee8w', 'review_count': 337, 'city': 'Clearwater'}
# {'business_id': 'nChGjLmmNEOjPOWNSOKoHA', 'review_count': 13, 'city': 'Alloway'}
# {'business_id': 'Y98PyhAegrju_1uIiX0K9g', 'review_count': 31, 'city': 'Holiday'}
# {'business_id': 'XhvipB9UUkXJ6iut_2v6nA', 'review_count': 14, 'city': 'East St Louis'}
# {'business_id': 'dMcozjibIHyFoo5IMDS_Dg', 'review_count': 17, 'city': 'Thonotosassa'}
# {'business_id': 'B8g_LoLP1mP9Xl3ec-HVUw', 'review_count': 12, 'city': 'Mount Laurel Township'}
# {'business_id': '3IB0q7sD6Y-PP-Qn-6wgiA', 'review_count': 8, 'city': 'Upper Chichester'}
# {'business_id': 'yK-MWTIYtcGd9ID0SWiarg', 'review_count': 41, 'city': 'S.Pasadena'}
# {'business_id': 'JM_XlMXEZEl8-nAcNHHtdg', 'review_count': 24, 'city': 'West Deptford'}
# {'business_id': 'kQANkgj6vHc1xCmxfNBNjA', 'review_count': 39, 'city': 'Westchase'}
# {'business_id': '3zrK7GMkM9zepbnE9KFWHg', 'review_count': 166, 'city': 'Camden'}
# {'business_id': 'aCIEDF2W4nRpL7fTk3njtw', 'review_count': 132, 'city': 'Fairless Hills'}
# {'business_id': 'nSFRFlanHCCITYyqYCP1bw', 'review_count': 96, 'city': 'Spring Hill'}
# {'business_id': '0aflm9H-XNg8eUAoeWmh9Q', 'review_count': 280, 'city': 'Marlton'}
# {'business_id': '5DPr9gtRh8ePwf9tOV6bqg', 'review_count': 27, 'city': 'Wenonah'}
# {'business_id': 'VPng2_ntju1nSoI8FHqmbg', 'review_count': 22, 'city': 'Laurel Springs'}
# {'business_id': 'XF2SR4yNnIOGRGH9goofuA', 'review_count': 869, 'city': 'St Petersburg'}
# {'business_id': '-1PG6k_iezwJmRZLB7f6og', 'review_count': 168, 'city': 'Zionsville'}
# {'business_id': 'gP5wF34lgcfI1yAaS4Vu4A', 'review_count': 74, 'city': 'erdenheim'}
# {'business_id': 'CfR34FRl5Eoka0rSusrfNA', 'review_count': 57, 'city': 'O Fallon'}
# {'business_id': 'haAIu_BLD6khheesCjKIRw', 'review_count': 268, 'city': 'Seminole'}
# {'business_id': '9xywJ1otUCj1kjiUGHSJCg', 'review_count': 117, 'city': 'Des Peres'}
# {'business_id': '3EXrZSNJd7RlEHYWP6Xsuw', 'review_count': 40, 'city': 'Bellmawr'}
# {'business_id': 'bLnC1_-Kd_Z5qhHNQXCUfQ', 'review_count': 349, 'city': 'Goleta'}
# {'business_id': 'b8yDHgkInh5WOhNT9TsUaw', 'review_count': 9, 'city': 'Southeast Edmonton'}
# {'business_id': 'IclzwxM1pbT3zxR-xHg3Cw', 'review_count': 11, 'city': 'Glenmore'}
# {'business_id': 's0yq79nfOrJEYoGKQLoxkg', 'review_count': 196, 'city': "Land O' Lakes"}
# {'business_id': 'FXYZkBtpaV5_HP-cfaHgbQ', 'review_count': 32, 'city': 'Summerland'}
# {'business_id': 'dCuMc7Q2lpSZRRqWVl69rA', 'review_count': 10, 'city': 'Winslow Township'}
# {'business_id': 'hzNsmcRGdcjcitrX2x0q4w', 'review_count': 39, 'city': 'Overland'}
# {'business_id': '7VrD6atyAIOPJAEdAvsA1g', 'review_count': 62, 'city': 'Hockessin'}
# {'business_id': 'ZJ7A2n82xW_xTk-p2yZOdQ', 'review_count': 30, 'city': 'Deptford'}
# {'business_id': 'HoxZwJdokeV0g_1n5L5OLw', 'review_count': 95, 'city': 'Glassboro'}
# {'business_id': 'pcsBMqZmpfVClemk43HhwA', 'review_count': 17, 'city': 'Holmes'}
# {'business_id': 'JURX4ptr4YV7gLEUBTRUCw', 'review_count': 58, 'city': 'Lahaska'}
# {'business_id': 'oBRv0szstOAamUktrBdVqA', 'review_count': 39, 'city': 'Paulsboro'}
# {'business_id': '3NaU6uRlb2owXc3oV0G25w', 'review_count': 83, 'city': 'Concord Township'}
# {'business_id': 'qma1sGQv7ArUtzuUTQElRg', 'review_count': 324, 'city': 'Town and Country'}
# {'business_id': 'xJ94mk1nysWsKD-UtXlKIA', 'review_count': 53, 'city': 'Truckee'}
# {'business_id': 'FcOkwzkHtoGJN5f0462ZmA', 'review_count': 43, 'city': 'Bridgeport'}
# {'business_id': 'i8epJgmh3rUonQDKx1g3hw', 'review_count': 23, 'city': 'Hulmeville'}
# {'business_id': 'PwkWZBL_FLDMheTnvg8zkg', 'review_count': 71, 'city': 'Chalmette'}
# {'business_id': 'q9m7n5eXcRSy4Wu92w7IIg', 'review_count': 11, 'city': 'Rillito'}
# {'business_id': 'FAvEJQ0E7n4f_Wasg9UvEw', 'review_count': 142, 'city': 'Harvey'}
# {'business_id': 'VDsp6_E_Ue0sCojaO_kTSw', 'review_count': 26, 'city': 'Berry Hill'}
# {'business_id': 'jA7MZB1aMgQaiNzIdhkwZg', 'review_count': 323, 'city': 'Lutz'}
# {'business_id': 'LGOGgAMIqxhuJbycvIwIdA', 'review_count': 57, 'city': 'Feasterville'}
# {'business_id': 'ZyOqGKdr5JetY4jgD_UoGw', 'review_count': 101, 'city': 'Bywater'}
# {'business_id': '8sfP7UGnmDowDQymGhNxhA', 'review_count': 80, 'city': 'Thornton'}
# {'business_id': 'Tj6d2FyZoUUOa8UjN1jDeg', 'review_count': 7, 'city': 'Franklinville'}
# {'business_id': 'RF2SocELaoYkXnZhxRcX0g', 'review_count': 166, 'city': 'Waterloo'}
# {'business_id': 'BZAVgg5ybeX_a4w-FW0mbA', 'review_count': 25, 'city': 'West Hill'}
# {'business_id': 'ZwazqfP1Eu78Imkh7goU_g', 'review_count': 14, 'city': 'Avondale'}
# {'business_id': 'NjAm2uGa4CoCqrcd2Pm8uA', 'review_count': 48, 'city': 'Westwego'}
# {'business_id': 'zLP7Ixx3IETkslUX9mNBSA', 'review_count': 5, 'city': 'Phonixville'}
# {'business_id': 'fLdPuGl9_fa9PYFYb0gihA', 'review_count': 91, 'city': 'Abington'}
# {'business_id': '9M3LdNG_QKTNOcqcUA5C3Q', 'review_count': 75, 'city': 'Southampton'}
# {'business_id': 'M8fwZcFBR_yrFSeF4Dw1-A', 'review_count': 22, 'city': 'Sun City Center'}
# {'business_id': 'yQXjZFhX9AE3e6tIo3r6gQ', 'review_count': 6, 'city': 'Belleair'}
# {'business_id': '6dqp7cO1B1qqHnzx63lA3A', 'review_count': 41, 'city': 'Oaklyn'}
# {'business_id': 'WuG54gebfU-juT5tNRHbKw', 'review_count': 38, 'city': 'Valley Park'}
# {'business_id': 'nXdBQ2ZHa-77cA5SJT0DjQ', 'review_count': 16, 'city': 'Salem'}
# {'business_id': 'SkdjIX5yRmvd3Bwug7ZpTA', 'review_count': 316, 'city': 'Chesterfield'}
# {'business_id': '1jWNdDn-t0IUpi2fGayCMg', 'review_count': 17, 'city': 'Riveridge'}
# {'business_id': 'U_x9aC9UabioGjJb9suzgQ', 'review_count': 6, 'city': 'Ashland City'}
# {'business_id': 'udqM5E5ATP-G6G1fQdQlnw', 'review_count': 92, 'city': 'Downingtown'}
# {'business_id': 'lpfrjbjIWC0BNZThaSDMLw', 'review_count': 91, 'city': 'Florissant'}
# {'business_id': 'z_RyP9WuygubNj--wuwuUQ', 'review_count': 20, 'city': 'Downtown'}
# {'business_id': 'zm4TZxLGRbGkhfw_aaMwnQ', 'review_count': 18, 'city': 'Rosemont'}
# {'business_id': 'HCYs4zgL7kCLdEqKRqaPbg', 'review_count': 664, 'city': 'St Louis'}
# {'business_id': 'f4RT5Pnv6DdfdvEexleGow', 'review_count': 41, 'city': 'Clarksboro'}
# {'business_id': 'qxRTFagnexBZgDe055CjkQ', 'review_count': 798, 'city': 'King of Prussia'}
# {'business_id': 'qI8XwSzwEm_jvJxk4oX38Q', 'review_count': 89, 'city': 'DELRAN'}
# {'business_id': 'huta5nl96oXBxnFIQeMTTA', 'review_count': 298, 'city': 'Wesley Chapel'}
# {'business_id': 'o8Q3OizUJiLwNGjehdpkcg', 'review_count': 235, 'city': 'Hudson'}
# {'business_id': 'A4rTUw6xBE3-wQLN_iaQEA', 'review_count': 77, 'city': 'Smyrna'}
# {'business_id': '5DDdiTlpK6Z2fqFs4uSTQQ', 'review_count': 285, 'city': 'Phoenixville'}
# {'business_id': '0-hPFo4virH4_c6k_Z0jtQ', 'review_count': 11, 'city': 'Petersburg'}
# {'business_id': 'k2Cw-H-jAEMAEq_Sju5AyA', 'review_count': 40, 'city': 'Chadds Ford'}
# {'business_id': '9Bf4mhvCmA6sv0hpwi3jDw', 'review_count': 14, 'city': 'Cahokia'}
# {'business_id': 'PL-uVeJNFQ2p_01HnRt5oQ', 'review_count': 8, 'city': 'Silverdale'}
# {'business_id': 'qeNDgjAh-04_4FlLAx2mHQ', 'review_count': 57, 'city': 'Antioch'}
# {'business_id': 'EMVzeO5uCO-W3zHV8mMDyw', 'review_count': 5, 'city': 'Murfreesboro'}
# {'business_id': 'XyBe3WZgtYSV2iJm4Mkn2w', 'review_count': 115, 'city': 'Tarpon Springs'}
# {'business_id': 'p3-FsWgkrRlT18Mw5Z1tHg', 'review_count': 571, 'city': 'Pinellas Park'}
# {'business_id': '-nXZLIhPQcYYJiLI3weqGQ', 'review_count': 137, 'city': 'Pennington'}
# {'business_id': 'skY6r8WAkYqpV7_TxNm23w', 'review_count': 2588, 'city': 'Santa Barbara'}
# {'business_id': 'hjRxa6xpKOwnbUgGvVCE5Q', 'review_count': 849, 'city': 'Sparks'}
# {'business_id': 'lPFxRE60qsZEMm-lxTNixQ', 'review_count': 66, 'city': 'Edgewater Park'}
# {'business_id': 'aUJh_PRVbNiYzOYUaVik2g', 'review_count': 5, 'city': 'Nampa'}
# {'business_id': '5x_8QDgcQE1PhU67ZZgJnw', 'review_count': 21, 'city': 'Gibbsboro'}
# {'business_id': 'EjwrtCJDCZBUS_uTvpHMSw', 'review_count': 92, 'city': 'Blackwood'}
# {'business_id': '-6bmADDPKp0HrT2wqAMjQw', 'review_count': 21, 'city': 'McCarran'}
# {'business_id': 'EGq4IvySG57-OJ13cZn7Kg', 'review_count': 49, 'city': 'Sunset Hills'}
# {'business_id': 'iXGdjMPaIfXpkpZHGVMsBg', 'review_count': 7, 'city': 'Wallingford'}
# {'business_id': 'oYzq49fG7jokPLQ38bFMOw', 'review_count': 268, 'city': 'Chalfont'}
# {'business_id': 'xloFoRiYlH4IKGz3FhTDpA', 'review_count': 5, 'city': 'Terra Ceia'}
# {'business_id': '1lHtLaV7dCDJLg9cKuWhVg', 'review_count': 15, 'city': 'Darby'}
# {'business_id': '2bVR-HHvTHteXpoeky288w', 'review_count': 132, 'city': 'Town N Country'}
# {'business_id': 'sH6EONVlVasdvFXpTMlvNg', 'review_count': 17, 'city': 'Ivyland'}
# {'business_id': 'CG_NAd2OggmVEQjFOYsuTA', 'review_count': 301, 'city': 'Seffner'}
# {'business_id': 'LI2IxfxpyJg69rS5aeBOnQ', 'review_count': 6, 'city': 'Eagleville'}
# {'business_id': 'VjDJV7FrrgRnOauV86NTYw', 'review_count': 5, 'city': 'Landsdale'}
# {'business_id': 'HOKw9p_OsGemuphPbULLlw', 'review_count': 9, 'city': 'Belle Meade'}
# {'business_id': '-FZYb_CFhjOZIVGj1tRB4w', 'review_count': 94, 'city': 'Bridgeton'}
# {'business_id': 'Q4_uwzXOKX5jv1I6SBR9ig', 'review_count': 191, 'city': 'Gulph Mills'}
# {'business_id': 'gbN4RuUiiBxQ2GBFQ2p3Cw', 'review_count': 7, 'city': 'Fernley'}
# {'business_id': 'qvlDimBAIxj9m-sk0eIizQ', 'review_count': 24, 'city': 'Maple Glen'}
# {'business_id': 'RyndNvh5DEsywX76cAkpeg', 'review_count': 92, 'city': 'Goodlettsville'}
# {'business_id': 'JwY7Y-wLKkkbVvAECoAdiw', 'review_count': 16, 'city': 'Wimauma'}
# {'business_id': 'uamAUnL4ox5uXvjquY9wLg', 'review_count': 35, 'city': 'Pennsville'}
# {'business_id': 'rQ5xsCMH6Xdk4NnmdeA3Eg', 'review_count': 329, 'city': 'Pineville'}
# {'business_id': '-reeXxeQfRSvO7NXOdgKcg', 'review_count': 7, 'city': 'Washington Park'}
# {'business_id': 'Aeq1zp0xCYKK_Vtdq0iruQ', 'review_count': 8, 'city': 'Stroudsburg'}
# {'business_id': 'RUXWCVeTj-v7Lqp7EWfYnA', 'review_count': 170, 'city': 'Woodbury'}
# {'business_id': 'EVkUOkQgnhPzuvfmAZh0rQ', 'review_count': 186, 'city': 'Broomall'}
# {'business_id': 'jV_XOycEzSlTx-65W906pg', 'review_count': 9, 'city': 'Apollo beach'}
# {'business_id': 'bSrPqCgrqcHHSVQZtRufsw', 'review_count': 8, 'city': 'Erdenheim'}
# {'business_id': 'rpFT0AX5kqMdtbdNH-gvdA', 'review_count': 517, 'city': 'South Pasadena'}
# {'business_id': '2nnVlm-_T4wk1qOpycifPA', 'review_count': 52, 'city': 'Sicklerville'}
# {'business_id': 'AN2zHziC3W0K41u3xAY5GA', 'review_count': 39, 'city': 'Saint Louis,'}
# {'business_id': '2AVA3WSH76LXCCBEzSKNqQ', 'review_count': 117, 'city': 'Lithia'}
# {'business_id': 'ZdXqFA7NLIcRATmaEn93jA', 'review_count': 113, 'city': 'Lansdowne'}
# {'business_id': '2t7bthCUHsu1BoZ-vdOpWg', 'review_count': 14, 'city': 'Stratford'}
# {'business_id': 'dpdiIXeYhGGsSvfBZHROEw', 'review_count': 318, 'city': 'Maryland Heights'}
# {'business_id': 'ZPjUG5wOJcQdNCbbqhVrdQ', 'review_count': 103, 'city': 'Bristol'}
# {'business_id': 'YKpZ2Ml0NZoYZ5eb3r_Cdg', 'review_count': 31, 'city': 'Freeburg'}
# {'business_id': 'DL5IVX_42Ra6DEq5d7NLrw', 'review_count': 448, 'city': 'Lambertville'}
# {'business_id': 'bwh7ozWD_qk6Ebzvac4eQA', 'review_count': 36, 'city': 'Pine Hill'}
# {'business_id': 'ReV4Q3rEJ8neicQPc6pC0w', 'review_count': 2079, 'city': 'Indianapolis'}
# {'business_id': 'So5ynsJSVB1qaDek1oXvXg', 'review_count': 662, 'city': 'Brandon'}
# {'business_id': 'oo54fNfXC7IkxwpeoPE15w', 'review_count': 196, 'city': 'Fairview Heights'}
# {'business_id': 'p4nvvj1QEEo5AJUbz5k2Pw', 'review_count': 61, 'city': 'Elmwood'}
# {'business_id': 'c21fgdWZTPmyC_z0cEMDnw', 'review_count': 69, 'city': 'Dresher'}
# {'business_id': 'Qh_-fezWEMPGv51YdZbXQg', 'review_count': 6, 'city': 'Dover'}
# {'business_id': 'rJ7D4HDkFqMy5SQuh6IV9A', 'review_count': 13, 'city': 'Haddon Township'}
# {'business_id': 'SYTZjphsAyR8Nmna37SCew', 'review_count': 7, 'city': 'Rutledge'}
# {'business_id': 'NKy_0iOBR19xR3jjAVHGVw', 'review_count': 20, 'city': 'Edgemont'}
# {'business_id': '5YiJYVLu05wY_Z9S-FyK2g', 'review_count': 21, 'city': 'Lawrence'}
# {'business_id': 'X_8cpc1p7R6KhFFKt3OkTA', 'review_count': 6, 'city': 'Normandy'}
# {'business_id': 'y0_n8AHgfhIjIF3z4lRQwQ', 'review_count': 83, 'city': 'Media'}
# {'business_id': 'lMmqQHYwwp_fDAHFbeDadg', 'review_count': 89, 'city': 'Pennsburg'}
# {'business_id': 'BjjmJvMPebz6cLMDwEmJ5A', 'review_count': 23, 'city': 'Saint Rose'}
# {'business_id': '9O_cHOFdyPYLTGaCUVAbqg', 'review_count': 12, 'city': 'Upper Merion Township'}
# {'business_id': 'mdlWkVgVv7Tgn3OlZGUxIQ', 'review_count': 85, 'city': 'Green Valley'}
# {'business_id': 'kUR59XFQps7CwVlo43wIlg', 'review_count': 20, 'city': 'Speedway'}
# {'business_id': 'mGvrybwAiigeSAn-sTNlCQ', 'review_count': 42, 'city': 'Ferguson'}
# {'business_id': 'MRANmFLBso31ZIshSjB7EA', 'review_count': 54, 'city': 'Tuscon'}
# {'business_id': 'qoCT7RlLwxpTLd4RDptvpQ', 'review_count': 13, 'city': 'Warminster '}
# {'business_id': 'Z81IX5aTaIEGa8QeWhJ-eA', 'review_count': 119, 'city': 'Maple Shade'}
# {'business_id': 'e2DMbDxbA_Ur7A18mGuRsg', 'review_count': 10, 'city': 'Lester'}
# {'business_id': '_ZMf5Am_e0AE7aveELJd9w', 'review_count': 140, 'city': 'Kennett Square'}
# {'business_id': 'WzS9lfYg9SKF36uZstKEfQ', 'review_count': 31, 'city': 'Jamison'}
# {'business_id': 'k4-QGDS29Db7YX2ZbSzG1g', 'review_count': 38, 'city': 'Glenolden'}
# {'business_id': 'Zqp948S83NutlJxDfd1VjA', 'review_count': 33, 'city': 'Clifton Heights'}
# {'business_id': 'FbNVmZsdNul0NkaZgHusSQ', 'review_count': 51, 'city': 'Kingston Springs'}
# {'business_id': 'M6HLdXfSf9Zpj1y8xxfimg', 'review_count': 8, 'city': 'Pontoon Beach'}
# {'business_id': '1xHs49XOvishqrkyX0v1vA', 'review_count': 29, 'city': 'Dade City'}
# {'business_id': 'hm7YQpJlaeMKh2QGtWVhtg', 'review_count': 280, 'city': 'Springfield'}
# {'business_id': 'rYa4K17ISr6elntmOUgayA', 'review_count': 9, 'city': 'New Washoe City'}
# {'business_id': 'r7iK-eZzarezCOIChpa8hA', 'review_count': 58, 'city': 'Aston'}
# {'business_id': 'yEKmlxvhA2EWrMLbwWi7Hw', 'review_count': 239, 'city': 'Bala Cynwyd'}
# {'business_id': 'xexO4AreHYE4JQTg6OlIeA', 'review_count': 10, 'city': 'Hammonton'}
# {'business_id': '0p_Y0p9FBDycE99DhcGK-A', 'review_count': 63, 'city': 'Pottstown'}
# {'business_id': '0-2DF7wre9-4Y8PoQEaAcQ', 'review_count': 10, 'city': 'St.Pete Beach'}
# {'business_id': 'ypetvi7gxJHP-32ELu14uw', 'review_count': 161, 'city': 'River Ridge'}
# {'business_id': 'EF5Fpofz71Fo_UqUpZUYBQ', 'review_count': 235, 'city': 'Saint Pete Beach'}
# {'business_id': 'Uj5MG6Tnd0iQzbKr_l4vJw', 'review_count': 40, 'city': 'Elmer'}
# {'business_id': 'sMjjClYrGEXcTFG66qmg8A', 'review_count': 123, 'city': 'Columbia'}
# {'business_id': 'PoO8yYTxE3Sflyog9kbp4w', 'review_count': 174, 'city': 'Ardmore'}
# {'business_id': 'OZS3eB_ig62hnMmJznBTmA', 'review_count': 15, 'city': 'Cheltenham Township'}
# {'business_id': 'DorCmYVDR5wcCVvbCAvzEg', 'review_count': 628, 'city': 'Riverview'}
# {'business_id': 'Honx3MgPQuiG72yA0oFOhw', 'review_count': 39, 'city': 'Camby'}
# {'business_id': 'Zh1cd9cjlCBFyrPbtC_4dA', 'review_count': 13, 'city': 'Rock Hill'}
# {'business_id': 'F-NLo63QqYWQX59M_nNZmg', 'review_count': 59, 'city': 'Sherwood Park'}
# {'business_id': 'Jo2zJoA818OmbiE-6HfghA', 'review_count': 122, 'city': 'Bensalem'}
# {'business_id': '72Vrhf0cLnr1zdata6hshA', 'review_count': 10, 'city': 'New Palestine'}
# {'business_id': 'jE8o7lX3NMmcG0iMlqoo7A', 'review_count': 85, 'city': 'Buckingham'}
# {'business_id': 'Gj-KAhvGJ8PNy1xo-vOMDg', 'review_count': 45, 'city': 'Webster Groves'}
# {'business_id': 'KfMw3tAjm09xsbUey-LehA', 'review_count': 23, 'city': 'Willingboro'}
# {'business_id': '7jCKXwau87h2YJI3fn5bIw', 'review_count': 13, 'city': 'Chester'}
# {'business_id': '4utFe1ob6ss68P6sgrw3ug', 'review_count': 74, 'city': 'Lake Saint Louis'}
# {'business_id': 'Di96sKUk5wo5P1bM3pv4FQ', 'review_count': 37, 'city': 'Lawnside'}
# {'business_id': 'tccw4OnMjHCoQ_Y0A145cw', 'review_count': 36, 'city': 'Woodbury Heights'}
# {'business_id': 'csspV7_Rmf6QnKeHIEVdFQ', 'review_count': 67, 'city': 'St. Charles'}
# {'business_id': 'nb_gbA9ZDT_t4QedmqOw0A', 'review_count': 88, 'city': 'Mt. Laurel'}
# {'business_id': '2YwUMLMj1Be6ogqwpTDqbg', 'review_count': 7, 'city': 'Trainer'}
# {'business_id': 'qDgR8XtZ0-P3DCDF9YccPw', 'review_count': 21, 'city': 'Mount Ephraim'}
# {'business_id': '3LSYzek9a1Xho8uPEFe29w', 'review_count': 138, 'city': 'Sappington'}
# {'business_id': 'tL0RRLZ8oQTmaee14lubqg', 'review_count': 72, 'city': 'Ridley Park'}
# {'business_id': 'JjYmXia9-Dy0tGqI088Hfg', 'review_count': 176, 'city': 'Berwyn'}
# {'business_id': '2g81Npe8smhqDBj897xllA', 'review_count': 5, 'city': 'Alberta Park Industrial'}
# {'business_id': 'FnRbuHh40BPB4u2RfJBUmQ', 'review_count': 10, 'city': 'Brookhaven'}
# {'business_id': 'QpK7QS5rluvEGeNB8LM_UA', 'review_count': 117, 'city': 'Collinsville'}
# {'business_id': 'wMGjF3eTtmkOPudjV_z--Q', 'review_count': 203, 'city': 'Edwardsville'}
# {'business_id': 'xrYL3EjqPjPTaN6lAEb2Pg', 'review_count': 169, 'city': 'Palmetto'}

# %% [markdown]
# ### (6. Top 5 Restaurants with >1000 reviews and >=4 stars in each city/state)

# %%
cur.execute("""
SELECT b.city, b.state, b.name, b.stars, b.review_count
FROM business b
WHERE b.categories ILIKE '%Restaurants%'
AND b.review_count > 1000
AND b.stars >= 4
ORDER BY b.city, b.state, b.stars DESC, b.review_count DESC
LIMIT 5;
""")

results = cur.fetchall()
print("Top 5 Restaurants with >1000 Reviews and 4+ Stars Per City/State:")
for row in results:
    print(row)
# Out:
#  Top 5 Restaurants with >1000 Reviews and 4+ Stars Per City/State:
# ('Boise', 'ID', 'Fork', 4.0, 1810)
# ('Boise', 'ID', 'Barbacoa Grill', 4.0, 1099)
# ('Clearwater', 'FL', 'Clear Sky Cafe', 4.5, 1824)
# ('Clearwater Beach', 'FL', "Frenchy's Rockaway Grill", 4.0, 2301)
# ('Clearwater Beach', 'FL', 'Columbia Restaurant', 4.0, 1017)

# %%
cur.execute("""
EXPLAIN ANALYZE
SELECT DISTINCT ON (b.city) b.city, b.name, b.review_count
FROM business b
ORDER BY b.city, b.review_count DESC;
""")

plan = cur.fetchall()
print("Execution Plan for Top 5 Restaurants with >1000 Reviews and 4+ Stars Per City/State")
for line in plan:
    print(line[0])
# Out:
# Execution Plan for Top 5 Restaurants with >1000 Reviews and 4+ Stars Per City/State
# Unique  (cost=31928.16..32679.89 rows=780 width=34) (actual time=174.860..198.058 rows=1416 loops=1)
#   ->  Sort  (cost=31928.16..32304.02 rows=150346 width=34) (actual time=174.859..192.989 rows=150346 loops=1)
#         Sort Key: city, review_count DESC
#         Sort Method: external merge  Disk: 6744kB
#         ->  Seq Scan on business b  (cost=0.00..14887.46 rows=150346 width=34) (actual time=0.015..49.971 rows=150346 loops=1)
# Planning Time: 0.106 ms
# Execution Time: 201.375 ms

# %% [markdown]
# ## MongoDB version our Benchmark

# %%
# pipeline = [
#     {
#         "$lookup": {
#             "from": "business",
#             "localField": "business_id",
#             "foreignField": "business_id",
#             "as": "business_info"
#         }
#     },
#     { "$unwind": "$business_info" },
#     {
#         "$group": {
#             "_id": "$user_id",
#             "cities_reviewed": { "$addToSet": "$business_info.city" }
#         }
#     },
#     {
#         "$addFields": {
#             "num_cities": { "$size": "$cities_reviewed" }
#         }
#     },
#     {
#         "$match": {
#             "num_cities": { "$gte": 3 }
#         }
#     },
#     { "$sort": { "num_cities": -1 } },
#     { "$limit": 10 }
# ]


pipeline = [
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_info"
        }
    },
    { "$unwind": "$business_info" },
    {
        "$group": {
            "_id": "$user_id",
            "unique_cities": { "$addToSet": "$business_info.city" }
        }
    },
    {
        "$match": {
            "$expr": { "$gte": [{ "$size": "$unique_cities" }, 3] }
        }
    },
    { "$sort": { "city_count": -1 } },
    { "$limit": 10 }
]



results = list(db.review.aggregate(pipeline))
print("Users Who Reviewed in 3+ Cities (MongoDB):")
pprint.pprint(result)
for row in results:
    print(f"Number of results: {len(results)}")
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /var/folders/l_/qqmwldsd40dccgp2bsqp6cx00000gn/T/ipykernel_4809/3931954151.py in <module>
#      65
#      66
# ---> 67 results = list(db.review.aggregate(pipeline))
#      68 print("Users Who Reviewed in 3+ Cities (MongoDB):")
#      69 pprint.pprint(result)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    2702                 let=let,
#    2703                 comment=comment,
# -> 2704                 **kwargs,
#    2705             )
#    2706
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2607             session,
#    2608             retryable=not cmd._performs_write,
# -> 2609             operation=_Op.AGGREGATE,
#    2610         )
#    2611
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1541             read_pref=read_pref,
#    1542             retryable=retryable,
# -> 1543             operation_id=operation_id,
#    1544         )
#    1545
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1498             address=address,
#    1499             retryable=retryable,
# -> 1500             operation_id=operation_id,
#    1501         ).run()
#    1502
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in run(self)
#    2345             self._check_last_error(check_csot=True)
#    2346             try:
# -> 2347                 return self._read() if self._is_read else self._write()
#    2348             except ServerSelectionTimeoutError:
#    2349                 # The application may think the write was never attempted
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _read(self)
#    2475         :return: Output for func()'s call
#    2476         """
# -> 2477         self._server = self._get_server()
#    2478         assert self._read_pref is not None, "Read Preference required on read calls"
#    2479         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server(self)
#    2437             address=self._address,
#    2438             deprioritized_servers=self._deprioritized_servers,
# -> 2439             operation_id=self._operation_id,
#    2440         )
#    2441
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1318                     operation,
#    1319                     deprioritized_servers=deprioritized_servers,
# -> 1320                     operation_id=operation_id,
#    1321                 )
#    1322             return server
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     372             address,
#     373             deprioritized_servers,
# --> 374             operation_id=operation_id,
#     375         )
#     376         if _csot.get_timeout():
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     345     ) -> Server:
#     346         servers = self.select_servers(
# --> 347             selector, operation, server_selection_timeout, address, operation_id
#     348         )
#     349         servers = _filter_servers(servers, deprioritized_servers)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     252         with self._lock:
#     253             server_descriptions = self._select_servers_loop(
# --> 254                 selector, server_timeout, operation, operation_id, address
#     255             )
#     256
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     302                     )
#     303                 raise ServerSelectionTimeoutError(
# --> 304                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     305                 )
#     306
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 68192e8ae7f19cf8ad39cdbd, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# cur.close()
# conn.close()
